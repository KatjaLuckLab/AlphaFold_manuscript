# %% [markdown]
# ### This notebook contains the codes to generate all the plots used in the manuscript.
# ### Author: Chop Yan Lee

# %%
import pandas as pd
import numpy as np
import scipy.stats as sp
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import seaborn as sns
import sqlalchemy, db_utils, glob, os, requests, itertools, re, shutil
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
from statannotations.Annotator import Annotator
colors = sns.color_palette("hls",14)
plt.rcParams['pdf.fonttype'] = 42 # Set the fonttype to export fonts as font files
plt.rcParams['font.family'] = 'Arial'
sns.set_palette("colorblind")
global_fontsize = 12
figsize = (3,3)
legend_fontsize = 8
bbox_to_anchor =(1, 1)
global_color = 'tab:grey'
connect = db_utils.get_connection()
save_path= '/Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/Plots/DMI_types_extensions/AF2_MMv2.2/'
con = db_utils.get_connection()

# %%
def modify_ticks_and_labels(ax,x_major_multiple=None,x_minor_multiple=None,
                            y_major_multiple=None,y_minor_multiple=None,change_markersize=False):
    global global_fontsize
    if x_major_multiple is not None:
        ax.tick_params(axis='x', which='both',labelsize=global_fontsize)
        ax.xaxis.set_major_locator(MultipleLocator(x_major_multiple))
        ax.xaxis.set_minor_locator(MultipleLocator(x_minor_multiple))
    if y_major_multiple is not None:
        ax.tick_params(axis='y', which='both',labelsize=global_fontsize)
        ax.yaxis.set_major_locator(MultipleLocator(y_major_multiple))
        ax.yaxis.set_minor_locator(MultipleLocator(y_minor_multiple))
    if change_markersize:
        plt.setp(ax.xaxis.get_majorticklines(), 'markersize', 5)
        plt.setp(ax.xaxis.get_majorticklines(), 'markeredgewidth', 2)
        plt.setp(ax.xaxis.get_minorticklines(), 'markersize', 3.5)
        plt.setp(ax.xaxis.get_minorticklines(), 'markeredgewidth', 2)
        plt.setp(ax.yaxis.get_majorticklines(), 'markersize', 5)
        plt.setp(ax.yaxis.get_majorticklines(), 'markeredgewidth', 2)
        plt.setp(ax.yaxis.get_minorticklines(), 'markersize', 3.5)
        plt.setp(ax.yaxis.get_minorticklines(), 'markeredgewidth', 2)
    plt.tick_params(axis= 'both', labelsize= global_fontsize)

# %% [markdown]
# ----
# ### Gather and preprocess the data needed for plotting later

# %%
# read in a list of DMI types so that I can parse the dmi names out of the prediction name
query = """select distinct dmi_type from chopyan_db.AF2_DMI_structure_PRS where for_AF2_benchmark = 1;"""
dmi_types = pd.read_sql_query(query,con=con)
dmi_types = dmi_types['dmi_type'].to_list()
dmi_types
# Out:
# ['DEG_APCC_KENBOX_2',
#  'DEG_COP1_1',
#  'DEG_Kelch_Keap1_1',
#  'DEG_Kelch_Keap1_2',
#  'DEG_MDM2_SWIB_1',
#  'DEG_SCF_COI1_1',
#  'DEG_SCF_TIR1_1',
#  'DEG_SIAH_1',
#  'DEG_SPOP_SBC_1',
#  'DOC_AGCK_PIF_3',
#  'DOC_ANK_TNKS_1',
#  'DOC_CYCLIN_RxL_1',
#  'DOC_GSK3_Axin_1',
#  'DOC_MAPK_DCC_7',
#  'DOC_MAPK_GRA24_9',
#  'DOC_MAPK_HePTP_8',
#  'DOC_MAPK_JIP1_4',
#  'DOC_MAPK_MEF2A_6',
#  'DOC_MAPK_NFAT4_5',
#  'DOC_MAPK_RevD_3',
#  'DOC_PP1_MyPhoNE_1',
#  'DOC_PP1_RVXF_1',
#  'DOC_PP1_SILK_1',
#  'DOC_PP2B_PxIxI_1',
#  'DOC_SPAK_OSR1_1',
#  'DOC_USP7_MATH_1',
#  'DOC_USP7_MATH_2',
#  'DOC_USP7_UBL2_3',
#  'LIG_14-3-3_ChREBP_3',
#  'LIG_Actin_RPEL_3',
#  'LIG_Actin_WH2_1',
#  'LIG_Actin_WH2_2',
#  'LIG_ANK_PxLPxL_1',
#  'LIG_AP2alpha_1',
#  'LIG_AP2alpha_2',
#  'LIG_APCC_ABBA_1',
#  'LIG_ARL_BART_1',
#  'LIG_BH_BH3_1',
#  'LIG_BIR_III_2',
#  'LIG_BIR_III_3',
#  'LIG_CaM_IQ_9',
#  'LIG_CAP-Gly_1',
#  'LIG_CAP-Gly_2',
#  'LIG_CID_NIM_1',
#  'LIG_Clathr_ClatBox_1',
#  'LIG_Clathr_ClatBox_2',
#  'LIG_CNOT1_NIM_1',
#  'LIG_CORNRBOX',
#  'LIG_CSL_BTD_1',
#  'LIG_deltaCOP1_diTrp_1',
#  'LIG_Dynein_DLC8_1',
#  'LIG_EF_ALG2_ABM_1',
#  'LIG_EH_1',
#  'LIG_EH1_1',
#  'LIG_EVH1_1',
#  'LIG_EVH1_2',
#  'LIG_EVH1_3',
#  'LIG_FAT_LD_1',
#  'LIG_FXI_DFP_1',
#  'LIG_GBD_Chelix_1',
#  'LIG_GLEBS_BUB3_1',
#  'LIG_GYF',
#  'LIG_HOMEOBOX',
#  'LIG_KLC1_WD_1',
#  'LIG_LIR_Apic_2',
#  'LIG_LIR_Gen_1',
#  'LIG_LIR_LC3C_4',
#  'LIG_LIR_Nem_3',
#  'LIG_LRP6_Inhibitor_1',
#  'LIG_LSD1_SNAG_1',
#  'LIG_LYPXL_L_2',
#  'LIG_LYPXL_S_1',
#  'LIG_MAD2',
#  'LIG_MLH1_MIPbox_1',
#  'LIG_MYND_2',
#  'LIG_NBox_RRM_1',
#  'LIG_NRBOX',
#  'LIG_NRP_CendR_1',
#  'LIG_OCRL_FandH_1',
#  'LIG_PALB2_WD40_1',
#  'LIG_PAM2_1',
#  'LIG_PAM2_2',
#  'LIG_PCNA_APIM_2',
#  'LIG_PCNA_PIPBox_1',
#  'LIG_PCNA_TLS_4',
#  'LIG_PCNA_yPIPBox_3',
#  'LIG_PDZ_Class_1',
#  'LIG_PDZ_Class_2',
#  'LIG_PDZ_Class_3',
#  'LIG_PDZ_Wminus1_1',
#  'LIG_Pex14_1',
#  'LIG_Pex14_3',
#  'LIG_PROFILIN_1',
#  'LIG_PTAP_UEV_1',
#  'LIG_PTB_Apo_2',
#  'LIG_Rb_LxCxE_1',
#  'LIG_Rb_pABgroove_1',
#  'LIG_REV1ctd_RIR_1',
#  'LIG_RPA_C_Vert',
#  'LIG_SH3_2',
#  'LIG_SH3_3',
#  'LIG_SH3_CIN85_PxpxPR_1',
#  'LIG_Sin3_1',
#  'LIG_SPRY_1',
#  'LIG_SUFU_1',
#  'LIG_SUMO_SIM_anti_2',
#  'LIG_SUMO_SIM_par_1',
#  'LIG_TPR',
#  'LIG_TRAF2_1',
#  'LIG_TRAF2_2',
#  'LIG_TRFH_1',
#  'LIG_UFM1_UFIM_1',
#  'LIG_ULM_U2AF65_1',
#  'LIG_Vh1_VBS_1',
#  'LIG_WD40_WDR5_VDV_1',
#  'LIG_WD40_WDR5_WIN_1',
#  'LIG_WD40_WDR5_WIN_2',
#  'LIG_WW_1',
#  'MOD_PKB_1',
#  'MOD_SUMO_for_1',
#  'TRG_AP2beta_CARGO_1',
#  'TRG_ENDOCYTIC_2',
#  'TRG_ER_FFAT_1',
#  'TRG_LysEnd_GGAAcLL_1',
#  'TRG_NES_CRM1_1',
#  'TRG_NLS_Bipartite_1',
#  'TRG_PTS1',
#  'DEG_SCF_FBXO31_1',
#  'DOC_CDC14_PxL_1',
#  'DOC_MIT_MIM_1',
#  'LIG_ActinCP_CPI_1',
#  'LIG_ActinCP_TwfCPI_2',
#  'LIG_KLC1_Yacidic_2',
#  'LIG_LYPXL_SIV_4',
#  'TRG_DiLeu_BaEn_1',
#  'TRG_DiLeu_BaLyEn_6']

# %%
def parse_prediction_name(prediction_name,DMI_name_list):
    """Parse out different components in the standard name for a minimal DMI prediction (e.g. run51_DEG_APCC_KENBOX_2_MFL_DFL)

    Args:
        prediction_name (str): Name of the folder containing the AlphaFold predicted structure
        DMI_name_list (list of str): A list of DMI types

    Returns:
        run_id (str): Run ID
        dmi_name (str): Name of DMI type
        seq_annot (str): start and end of the extended model (e.g. M31_M45_Dmin)
    """
    splits = prediction_name.split('_')
    run_id = splits[0]
    temp = '_'.join(splits[1:])
    for dmi_name in DMI_name_list:
        match = re.search(dmi_name,temp)
        if match is not None:
            seq_annot = temp[match.end()+1:]
            return [run_id, dmi_name]
        
query = f"""select * from chopyan_db.AlphaFold_prediction_result
where run_id in ('run39','run40','run46') and project_name = 'AlphaFold_benchmark'"""

ext_df = pd.read_sql_query(query,con=con)

ext_df[['run_id','dmi_name']] = ext_df.apply(lambda x: parse_prediction_name(x['prediction_name'],dmi_types),
                                            axis=1,result_type='expand')
ext_df
# Out:
#              project_name                          prediction_name run_id  \
# 0     AlphaFold_benchmark  run39_DEG_APCC_KENBOX_2_M15_M39_D1_D499  run39
# 1     AlphaFold_benchmark  run39_DEG_APCC_KENBOX_2_M15_M39_D1_D499  run39
# 2     AlphaFold_benchmark  run39_DEG_APCC_KENBOX_2_M15_M39_D1_D499  run39
# 3     AlphaFold_benchmark  run39_DEG_APCC_KENBOX_2_M15_M39_D1_D499  run39
# 4     AlphaFold_benchmark  run39_DEG_APCC_KENBOX_2_M15_M39_D1_D499  run39
# ...                   ...                                      ...    ...
# 3630  AlphaFold_benchmark  run46_TRG_AP2beta_CARGO_1_MFL_D542_D937  run46
# 3631  AlphaFold_benchmark  run46_TRG_AP2beta_CARGO_1_MFL_D542_D937  run46
# 3632  AlphaFold_benchmark  run46_TRG_AP2beta_CARGO_1_MFL_D542_D937  run46
# 3633  AlphaFold_benchmark  run46_TRG_AP2beta_CARGO_1_MFL_D542_D937  run46
# 3634  AlphaFold_benchmark  run46_TRG_AP2beta_CARGO_1_MFL_D542_D937  run46
#
#       chainA_length  chainB_length  model_id  model_confidence  \
# 0               499             25  ranked_0          0.722553
# 1               499             25  ranked_1          0.710868
# 2               499             25  ranked_2          0.706698
# 3               499             25  ranked_3          0.689345
# 4               499             25  ranked_4          0.679946
# ...             ...            ...       ...               ...
# 3630            396            308  ranked_0          0.519132
# 3631            396            308  ranked_1          0.512356
# 3632            396            308  ranked_2          0.511914
# 3633            396            308  ranked_3          0.511698
# 3634            396            308  ranked_4          0.474777
#
#       chainA_intf_avg_plddt  chainB_intf_avg_plddt  intf_avg_plddt  ...  \
# 0                 96.590455              87.037000       93.605000  ...
# 1                 96.486842              79.521250       91.460000  ...
# 2                 97.075000              88.953334       94.367778  ...
# 3                 96.403889              86.464444       93.090740  ...
# 4                 96.648889              84.273749       92.841154  ...
# ...                     ...                    ...             ...  ...
# 3630              88.859131              70.085000       80.616830  ...
# 3631              91.195652              63.080870       77.138261  ...
# 3632              91.277500              79.195332       86.099428  ...
# 3633              86.413214              76.311818       81.968600  ...
# 3634              91.664000              72.964000       83.649714  ...
#
#       align_score_domain  num_align_resi_domain  RMSD_backbone_peptide  \
# 0                 1681.0                    312               0.782261
# 1                 1681.0                    312               0.806960
# 2                 1681.0                    312               0.631923
# 3                 1681.0                    312               0.601806
# 4                 1681.0                    312               0.548377
# ...                  ...                    ...                    ...
# 3630              1224.0                    233               0.443842
# 3631              1224.0                    233               0.415850
# 3632              1224.0                    233               0.513621
# 3633              1224.0                    233               0.462627
# 3634              1224.0                    233               0.465192
#
#       RMSD_all_atom_peptide  known_motif_plddt  DockQ   iRMS   LRMS  Fnonnat  \
# 0                  0.976217          94.320000  0.956  0.462  0.747    0.074
# 1                  0.949021          88.406001  0.952  0.379  0.768    0.040
# 2                  0.898317          93.689999  0.961  0.420  0.583    0.138
# 3                  0.860603          92.514000  0.957  0.336  0.560    0.111
# 4                  0.844121          91.944000  0.957  0.337  0.504    0.000
# ...                     ...                ...    ...    ...    ...      ...
# 3630               1.206194          88.205454  0.947  0.377  0.433    0.067
# 3631               1.219476          88.829090  0.946  0.390  0.420    0.034
# 3632               1.353208          87.522727  0.941  0.433  0.502    0.034
# 3633               1.287532          86.066363  0.954  0.417  0.461    0.065
# 3634               1.248228          84.925455  0.945  0.398  0.459    0.067
#
#                  dmi_name
# 0       DEG_APCC_KENBOX_2
# 1       DEG_APCC_KENBOX_2
# 2       DEG_APCC_KENBOX_2
# 3       DEG_APCC_KENBOX_2
# 4       DEG_APCC_KENBOX_2
# ...                   ...
# 3630  TRG_AP2beta_CARGO_1
# 3631  TRG_AP2beta_CARGO_1
# 3632  TRG_AP2beta_CARGO_1
# 3633  TRG_AP2beta_CARGO_1
# 3634  TRG_AP2beta_CARGO_1
#
# [3635 rows x 28 columns]

# %%
# check how predictions did not go through as some long predictions are tricky
ext_df[ext_df['model_id'] == 'Prediction failed'].shape
# Out:
# (0, 28)

# %%
# I made the mistake of duplicating some extensions as full length because some proteins after extension becomes
# full length, these should be de-duplicated
# I also only work with the best model as selected by the least RMSD_all_atom_peptide per predicton,
# the de-duplication will also filter for best model per prediction
final_df = ext_df.sort_values(['RMSD_all_atom_peptide'],ascending=True).drop_duplicates(subset=['dmi_name','chainA_length',
                                                                           'chainB_length'],keep='first').copy()
final_df.reset_index(drop=True,inplace=True)
print(final_df.shape)
final_df
# Out:
# (703, 28)
#             project_name                          prediction_name run_id  \
# 0    AlphaFold_benchmark            run39_DEG_SIAH_1_M41_M85_Dmin  run39
# 1    AlphaFold_benchmark  run39_DOC_USP7_MATH_1_M392_M406_D1_D204  run39
# 2    AlphaFold_benchmark  run39_DOC_USP7_MATH_1_M392_M406_D1_D528  run39
# 3    AlphaFold_benchmark        run39_DEG_SIAH_1_M23_M103_D1_D282  run39
# 4    AlphaFold_benchmark         run39_DEG_SIAH_1_M41_M85_D1_D282  run39
# ..                   ...                                      ...    ...
# 698  AlphaFold_benchmark      run40_LIG_LRP6_Inhibitor_1_Mmin_DFL  run40
# 699  AlphaFold_benchmark        run46_LIG_CAP-Gly_2_M568_M581_DFL  run46
# 700  AlphaFold_benchmark             run40_LIG_CAP-Gly_1_Mmin_DFL  run40
# 701  AlphaFold_benchmark             run40_LIG_CAP-Gly_2_Mmin_DFL  run40
# 702  AlphaFold_benchmark        run46_LIG_CAP-Gly_2_M561_M581_DFL  run46
#
#      chainA_length  chainB_length  model_id  model_confidence  \
# 0              188             45  ranked_2          0.749542
# 1              204             15  ranked_0          0.774931
# 2              528             15  ranked_1          0.791709
# 3              282             81  ranked_2          0.526807
# 4              282             45  ranked_3          0.648164
# ..             ...            ...       ...               ...
# 698           1613              7  ranked_1          0.222651
# 699           1438             14  ranked_0          0.151068
# 700           1278              5  ranked_1          0.174906
# 701           1438              7  ranked_0          0.151363
# 702           1438             21  ranked_2          0.146456
#
#      chainA_intf_avg_plddt  chainB_intf_avg_plddt  intf_avg_plddt  ...  \
# 0                89.468124              61.922609       77.949091  ...
# 1                92.163889              75.586924       85.212258  ...
# 2                89.653125              67.089167       79.982857  ...
# 3                90.314230              67.109334       81.824634  ...
# 4                89.451112              56.308334       76.194001  ...
# ..                     ...                    ...             ...  ...
# 698                    NaN                    NaN             NaN  ...
# 699                    NaN                    NaN             NaN  ...
# 700                    NaN                    NaN             NaN  ...
# 701                    NaN                    NaN             NaN  ...
# 702                    NaN                    NaN             NaN  ...
#
#      align_score_domain  num_align_resi_domain  RMSD_backbone_peptide  \
# 0                 748.5                    146               0.325264
# 1                 722.5                    136               0.386834
# 2                 733.5                    137               0.446647
# 3                 748.5                    146               0.357424
# 4                 748.5                    146               0.335499
# ..                  ...                    ...                    ...
# 698              1649.0                    305             205.501190
# 699               255.0                     47             215.098099
# 700               250.0                     46             215.985611
# 701               255.0                     47             219.396851
# 702               255.0                     47             232.847885
#
#      RMSD_all_atom_peptide  known_motif_plddt  DockQ    iRMS     LRMS  \
# 0                 0.510364          90.693334  0.966   0.431    0.315
# 1                 0.523262          93.548001  0.967   0.337    0.387
# 2                 0.532916          83.765999  0.962   0.389    0.379
# 3                 0.541214          78.116668  0.966   0.426    0.357
# 4                 0.541225          88.134445  0.968   0.412    0.334
# ..                     ...                ...    ...     ...      ...
# 698             205.861694          18.710000  0.001  56.106  205.550
# 699             214.475967          31.508571  0.001  70.842  215.212
# 700             215.357544          28.294001  0.001  70.539  215.566
# 701             221.662048          27.205714  0.001  77.609  219.353
# 702             233.888992          24.710000  0.001  80.586  232.855
#
#      Fnonnat              dmi_name
# 0      0.071            DEG_SIAH_1
# 1      0.208       DOC_USP7_MATH_1
# 2      0.174       DOC_USP7_MATH_1
# 3      0.071            DEG_SIAH_1
# 4      0.093            DEG_SIAH_1
# ..       ...                   ...
# 698    0.000  LIG_LRP6_Inhibitor_1
# 699    0.000         LIG_CAP-Gly_2
# 700    0.000         LIG_CAP-Gly_1
# 701    0.000         LIG_CAP-Gly_2
# 702    0.000         LIG_CAP-Gly_2
#
# [703 rows x 28 columns]

# %%
# create motif extension step index 
# chainB is always the motif chain 
temp = final_df.drop_duplicates(subset=['dmi_name','chainB_length']).copy()
motif_ext_index_df = temp.sort_values(['dmi_name','chainB_length'])[['dmi_name','chainB_length']].copy()
motif_ext_index_df['motif_ext_index'] = [i for v in motif_ext_index_df.groupby('dmi_name').size().values for i in range(0,v)]
motif_ext_index_df.reset_index(drop=True,inplace=True)
motif_ext_index_df
# Out:
#                 dmi_name  chainB_length  motif_ext_index
# 0      DEG_APCC_KENBOX_2              5                0
# 1      DEG_APCC_KENBOX_2             15                1
# 2      DEG_APCC_KENBOX_2             25                2
# 3      DEG_APCC_KENBOX_2             45                3
# 4      DEG_APCC_KENBOX_2             57                4
# ..                   ...            ...              ...
# 229  TRG_AP2beta_CARGO_1             55                2
# 230  TRG_AP2beta_CARGO_1             97                3
# 231  TRG_AP2beta_CARGO_1            119                4
# 232  TRG_AP2beta_CARGO_1            271                5
# 233  TRG_AP2beta_CARGO_1            308                6
#
# [234 rows x 3 columns]

# %% [markdown]
# motif_ext_index 6 as the full length

# %%
# create domain extension step index 
# chainA is always the domain chain 
temp = final_df.drop_duplicates(subset=['dmi_name','chainA_length']).copy()
domain_ext_index_df = temp.sort_values(['dmi_name','chainA_length'])[['dmi_name','chainA_length']].copy()
domain_ext_index_df['domain_ext_index'] = [i for v in domain_ext_index_df.groupby('dmi_name').size().values for i in range(0,v)]
domain_ext_index_df.reset_index(drop=True,inplace=True)
domain_ext_index_df
# Out:
#                 dmi_name  chainA_length  domain_ext_index
# 0      DEG_APCC_KENBOX_2            307                 0
# 1      DEG_APCC_KENBOX_2            499                 1
# 2      DEG_Kelch_Keap1_1            280                 0
# 3      DEG_Kelch_Keap1_1            330                 1
# 4      DEG_Kelch_Keap1_1            450                 2
# ..                   ...            ...               ...
# 107             LIG_WW_1            438                 1
# 108  TRG_AP2beta_CARGO_1            232                 0
# 109  TRG_AP2beta_CARGO_1            396                 1
# 110  TRG_AP2beta_CARGO_1            934                 2
# 111  TRG_AP2beta_CARGO_1            937                 3
#
# [112 rows x 3 columns]

# %% [markdown]
# domain_ext_index 3 as the full length

# %%
final_df = pd.merge(final_df,domain_ext_index_df,how='outer',on=['dmi_name','chainA_length'])
final_df = pd.merge(final_df,motif_ext_index_df,how='outer',on=['dmi_name','chainB_length'])
final_df
# Out:
#             project_name                            prediction_name run_id  \
# 0    AlphaFold_benchmark              run39_DEG_SIAH_1_M41_M85_Dmin  run39
# 1    AlphaFold_benchmark           run39_DEG_SIAH_1_M41_M85_D1_D282  run39
# 2    AlphaFold_benchmark              run39_DEG_SIAH_1_M5_M121_Dmin  run39
# 3    AlphaFold_benchmark           run39_DEG_SIAH_1_M5_M121_D1_D282  run39
# 4    AlphaFold_benchmark             run39_DEG_SIAH_1_M23_M103_Dmin  run39
# ..                   ...                                        ...    ...
# 698  AlphaFold_benchmark   run40_LIG_CNOT1_NIM_1_M1_M89_D1377_D2376  run40
# 699  AlphaFold_benchmark          run39_LIG_CNOT1_NIM_1_M1_M89_Dmin  run39
# 700  AlphaFold_benchmark  run40_LIG_CNOT1_NIM_1_M1_M276_D1544_D2376  run40
# 701  AlphaFold_benchmark  run40_LIG_CNOT1_NIM_1_M1_M276_D1377_D2376  run40
# 702  AlphaFold_benchmark         run39_LIG_CNOT1_NIM_1_M1_M276_Dmin  run39
#
#      chainA_length  chainB_length  model_id  model_confidence  \
# 0              188             45  ranked_2          0.749542
# 1              282             45  ranked_3          0.648164
# 2              188            117  ranked_2          0.638711
# 3              282            117  ranked_2          0.578105
# 4              188             81  ranked_2          0.651657
# ..             ...            ...       ...               ...
# 698           1000             89  ranked_2          0.250435
# 699            432             89  ranked_4          0.277345
# 700            833            276  ranked_3          0.249178
# 701           1000            276  ranked_0          0.298145
# 702            432            276  ranked_2          0.249707
#
#      chainA_intf_avg_plddt  chainB_intf_avg_plddt  intf_avg_plddt  ...  \
# 0                89.468124              61.922609       77.949091  ...
# 1                89.451112              56.308334       76.194001  ...
# 2                86.530357              67.089444       78.923043  ...
# 3                89.676072              70.348235       82.374444  ...
# 4                88.818000              63.364287       79.680769  ...
# ..                     ...                    ...             ...  ...
# 698              60.305715              29.795000       46.223846  ...
# 699              71.933333              32.926471       51.210938  ...
# 700              71.964001              24.209285       52.300294  ...
# 701              85.526667              73.312001       79.097895  ...
# 702              71.190345              30.781923       52.088182  ...
#
#      RMSD_backbone_peptide  RMSD_all_atom_peptide  known_motif_plddt  DockQ  \
# 0                 0.325264               0.510364          90.693334  0.966
# 1                 0.335499               0.541225          88.134445  0.968
# 2                 0.359419               0.544323          79.068888  0.964
# 3                 0.373581               0.562924          80.512221  0.967
# 4                 0.375008               0.553687          74.640002  0.963
# ..                     ...                    ...                ...    ...
# 698              16.675762              16.607645          30.686000  0.095
# 699              19.187805              19.616602          32.162000  0.065
# 700              21.784376              22.200975          23.505000  0.053
# 701              28.551508              29.629011          19.876000  0.033
# 702              20.265190              20.449677          25.529000  0.059
#
#        iRMS    LRMS  Fnonnat         dmi_name  domain_ext_index  \
# 0     0.431   0.315    0.071       DEG_SIAH_1                 0
# 1     0.412   0.334    0.093       DEG_SIAH_1                 1
# 2     0.447   0.356    0.071       DEG_SIAH_1                 0
# 3     0.417   0.371    0.071       DEG_SIAH_1                 1
# 4     0.454   0.370    0.049       DEG_SIAH_1                 0
# ..      ...     ...      ...              ...               ...
# 698   7.554  16.711    0.857  LIG_CNOT1_NIM_1                 2
# 699   8.312  19.196    1.000  LIG_CNOT1_NIM_1                 0
# 700   8.990  21.843    1.000  LIG_CNOT1_NIM_1                 1
# 701  11.244  28.572    0.000  LIG_CNOT1_NIM_1                 2
# 702   8.788  20.268    1.000  LIG_CNOT1_NIM_1                 0
#
#      motif_ext_index
# 0                  2
# 1                  2
# 2                  4
# 3                  4
# 4                  3
# ..               ...
# 698                3
# 699                3
# 700                5
# 701                5
# 702                5
#
# [703 rows x 30 columns]

# %% [markdown]
# ### We later realized that some full length extensions (6th for motif extension and 3rd for domain extension) is marginal compared to the previous extension step. I have to manually check these cases and have them excluded from the analysis since the extensions are marginal and do not really count as meaningful extensions.

# %%
motif_ext_index_df.groupby('dmi_name').agg({'chainB_length':lambda x: ','.join(map(str,x)),
                                            'motif_ext_index':lambda x: ','.join(map(str,x))})
# Out:
#                                    chainB_length motif_ext_index
# dmi_name
# DEG_APCC_KENBOX_2         5,15,25,45,57,189,1050   0,1,2,3,4,5,6
# DEG_Kelch_Keap1_1          6,18,30,54,78,568,605   0,1,2,3,4,5,6
# DEG_MDM2_SWIB_1            8,24,40,58,74,298,393   0,1,2,3,4,5,6
# DEG_SIAH_1                9,27,45,81,117,166,228   0,1,2,3,4,5,6
# DOC_ANK_TNKS_1            8,24,40,72,104,322,350   0,1,2,3,4,5,6
# DOC_MAPK_JIP1_4            7,21,35,63,91,427,455   0,1,2,3,4,5,6
# DOC_SPAK_OSR1_1           5,15,25,45,65,801,1243   0,1,2,3,4,5,6
# DOC_USP7_MATH_1            5,15,25,45,65,202,491   0,1,2,3,4,5,6
# DOC_USP7_UBL2_3           5,15,25,37,42,682,1616   0,1,2,3,4,5,6
# LIG_BIR_III_2              5,15,25,45,65,266,416   0,1,2,3,4,5,6
# LIG_CAP-Gly_1                        5,7,33,1438         0,1,2,3
# LIG_CAP-Gly_2              7,14,21,35,49,462,581   0,1,2,3,4,5,6
# LIG_CNOT1_NIM_1          10,30,50,89,109,276,292   0,1,2,3,4,5,6
# LIG_EF_ALG2_ABM_1         9,27,45,81,117,466,868   0,1,2,3,4,5,6
# LIG_GYF                   9,27,45,81,111,227,351   0,1,2,3,4,5,6
# LIG_HOMEOBOX               4,12,20,36,52,270,301   0,1,2,3,4,5,6
# LIG_LIR_Gen_1            11,33,55,99,143,598,966   0,1,2,3,4,5,6
# LIG_LRP6_Inhibitor_1       7,21,35,63,85,149,266   0,1,2,3,4,5,6
# LIG_NBox_RRM_1           11,33,55,85,102,175,644   0,1,2,3,4,5,6
# LIG_NRBOX                 7,21,35,63,91,374,1464   0,1,2,3,4,5,6
# LIG_OCRL_FandH_1         13,39,53,79,105,238,249   0,1,2,3,4,5,6
# LIG_PAM2_1                    13,32,45,71,97,127     0,1,2,3,4,5
# LIG_PAM2_2             14,42,70,126,182,275,1690   0,1,2,3,4,5,6
# LIG_PCNA_PIPBox_1         10,30,41,61,81,154,164   0,1,2,3,4,5,6
# LIG_PCNA_TLS_4             8,17,25,41,57,470,870   0,1,2,3,4,5,6
# LIG_PDZ_Class_1           6,12,18,30,42,749,1601   0,1,2,3,4,5,6
# LIG_Pex14_3                6,18,30,54,78,412,639   0,1,2,3,4,5,6
# LIG_REV1ctd_RIR_1        12,36,60,99,123,470,870   0,1,2,3,4,5,6
# LIG_RPA_C_Vert          16,48,80,136,144,309,313   0,1,2,3,4,5,6
# LIG_TRFH_1                 5,15,25,45,65,442,451   0,1,2,3,4,5,6
# LIG_ULM_U2AF65_1           9,27,41,59,77,140,639   0,1,2,3,4,5,6
# LIG_Vh1_VBS_1         19,57,95,171,247,1788,2541   0,1,2,3,4,5,6
# LIG_WW_1                   4,11,15,23,31,299,895   0,1,2,3,4,5,6
# TRG_AP2beta_CARGO_1      11,33,55,97,119,271,308   0,1,2,3,4,5,6

# %% [markdown]
# Some full length motif extensions (step 6), is marginally different from step 5 that includes the neighboring domain. Katja said that those motif extension step 6 with less than 20 residues extended on either N or C terminus should be excluded from step 6. They are as follow:
#
# - LIG_CNOT1_NIM_1
# - LIG_OCRL_FandH_1
# - LIG_PCNA_PIPBox_1
# - LIG_RPA_C_Vert
# - LIG_TRFH_1

# %%
# prepare the indices of 6th motif extension step that will be excluded from analysis later
dmi_6th_motif_ext_marginal = ['LIG_CNOT1_NIM_1','LIG_OCRL_FandH_1','LIG_PCNA_PIPBox_1','LIG_RPA_C_Vert',
                             'LIG_TRFH_1']
dmi_6th_motif_ext_marginal_ind = final_df[(final_df['dmi_name'].isin(dmi_6th_motif_ext_marginal)) & (final_df['motif_ext_index'] == 6)].index
len(dmi_6th_motif_ext_marginal_ind)
# Out:
# 14

# %%
domain_ext_index_df.groupby('dmi_name').agg({'chainA_length':lambda x: ','.join(map(str,x)),
                                            'domain_ext_index':lambda x: ','.join(map(str,x))})
# Out:
#                           chainA_length domain_ext_index
# dmi_name
# DEG_APCC_KENBOX_2               307,499              0,1
# DEG_Kelch_Keap1_1       280,330,450,624          0,1,2,3
# DEG_MDM2_SWIB_1          75,290,337,491          0,1,2,3
# DEG_SIAH_1                      188,282              0,1
# DOC_ANK_TNKS_1         155,199,352,1166          0,1,2,3
# DOC_MAPK_JIP1_4                 351,464              0,1
# DOC_SPAK_OSR1_1          57,227,521,527          0,1,2,3
# DOC_USP7_MATH_1        138,204,528,1102          0,1,2,3
# DOC_USP7_UBL2_3        245,338,893,1102          0,1,2,3
# LIG_BIR_III_2            66,198,342,497          0,1,2,3
# LIG_CAP-Gly_1           41,517,815,1278          0,1,2,3
# LIG_CAP-Gly_2           42,204,288,1438          0,1,2,3
# LIG_CNOT1_NIM_1       432,833,1000,2376          0,1,2,3
# LIG_EF_ALG2_ABM_1               163,191              0,1
# LIG_GYF                          57,341              0,1
# LIG_HOMEOBOX             68,189,401,430          0,1,2,3
# LIG_LIR_Gen_1                   110,117              0,1
# LIG_LRP6_Inhibitor_1   300,362,422,1613          0,1,2,3
# LIG_NBox_RRM_1                  191,559              0,1
# LIG_NRBOX               207,281,422,595          0,1,2,3
# LIG_OCRL_FandH_1        334,368,667,901          0,1,2,3
# LIG_PAM2_1               68,264,351,636          0,1,2,3
# LIG_PAM2_2               72,264,351,636          0,1,2,3
# LIG_PCNA_PIPBox_1               250,261              0,1
# LIG_PCNA_TLS_4                  250,261              0,1
# LIG_PDZ_Class_1         91,308,510,2485          0,1,2,3
# LIG_Pex14_3                      64,377              0,1
# LIG_REV1ctd_RIR_1       94,200,250,1251          0,1,2,3
# LIG_RPA_C_Vert                   88,270              0,1
# LIG_TRFH_1              202,370,437,439          0,1,2,3
# LIG_ULM_U2AF65_1         99,136,225,475          0,1,2,3
# LIG_Vh1_VBS_1          253,471,925,1134          0,1,2,3
# LIG_WW_1                        256,438              0,1
# TRG_AP2beta_CARGO_1     232,396,934,937          0,1,2,3

# %% [markdown]
# After manual checking, the following DMI's domain extension step 3 will be excluded because their full length extensions differ marginally to that of domain extension step 2 (less than 20 residues on N or C terminal of the 2nd domain extension):
# - DOC_SPAK_OSR1_1, domain ext 3
# - LIG_TRFH_1, domain ext 3
# - TRG_AP2beta_CARGO_1, domain ext 3
#
# LIG_HOMEOBOX has 29 residue extension on the N terminus as the third domain extension step and that makes it okay to be included in the analysis.

# %%
# prepare the indices of 3rd domain extension step that will be excluded from analysis later
dmi_3rd_domain_ext_marginal = ['DOC_SPAK_OSR1_1','LIG_TRFH_1','TRG_AP2beta_CARGO_1']
dmi_3rd_domain_ext_marginal_ind = final_df[(final_df['dmi_name'].isin(dmi_3rd_domain_ext_marginal)) & (final_df['domain_ext_index'] == 3)].index
len(dmi_3rd_domain_ext_marginal_ind)
# Out:
# 19

# %%
# some indices are repeated in 3rd domain extension and 6th motif extension exclusion
# so make a union of the two lists first
len(set(dmi_3rd_domain_ext_marginal_ind).union(set(dmi_6th_motif_ext_marginal_ind)))
# Out:
# 32

# %%
# exclude the predictions involving 3rd domain extension that marginally extend the protein
final_df.drop(index=set(dmi_3rd_domain_ext_marginal_ind).union(set(dmi_6th_motif_ext_marginal_ind)),inplace=True)
final_df.reset_index(drop=True,inplace=True)
print(final_df.shape)
final_df
# Out:
# (671, 30)
#             project_name                            prediction_name run_id  \
# 0    AlphaFold_benchmark              run39_DEG_SIAH_1_M41_M85_Dmin  run39
# 1    AlphaFold_benchmark           run39_DEG_SIAH_1_M41_M85_D1_D282  run39
# 2    AlphaFold_benchmark              run39_DEG_SIAH_1_M5_M121_Dmin  run39
# 3    AlphaFold_benchmark           run39_DEG_SIAH_1_M5_M121_D1_D282  run39
# 4    AlphaFold_benchmark             run39_DEG_SIAH_1_M23_M103_Dmin  run39
# ..                   ...                                        ...    ...
# 666  AlphaFold_benchmark   run40_LIG_CNOT1_NIM_1_M1_M89_D1377_D2376  run40
# 667  AlphaFold_benchmark          run39_LIG_CNOT1_NIM_1_M1_M89_Dmin  run39
# 668  AlphaFold_benchmark  run40_LIG_CNOT1_NIM_1_M1_M276_D1544_D2376  run40
# 669  AlphaFold_benchmark  run40_LIG_CNOT1_NIM_1_M1_M276_D1377_D2376  run40
# 670  AlphaFold_benchmark         run39_LIG_CNOT1_NIM_1_M1_M276_Dmin  run39
#
#      chainA_length  chainB_length  model_id  model_confidence  \
# 0              188             45  ranked_2          0.749542
# 1              282             45  ranked_3          0.648164
# 2              188            117  ranked_2          0.638711
# 3              282            117  ranked_2          0.578105
# 4              188             81  ranked_2          0.651657
# ..             ...            ...       ...               ...
# 666           1000             89  ranked_2          0.250435
# 667            432             89  ranked_4          0.277345
# 668            833            276  ranked_3          0.249178
# 669           1000            276  ranked_0          0.298145
# 670            432            276  ranked_2          0.249707
#
#      chainA_intf_avg_plddt  chainB_intf_avg_plddt  intf_avg_plddt  ...  \
# 0                89.468124              61.922609       77.949091  ...
# 1                89.451112              56.308334       76.194001  ...
# 2                86.530357              67.089444       78.923043  ...
# 3                89.676072              70.348235       82.374444  ...
# 4                88.818000              63.364287       79.680769  ...
# ..                     ...                    ...             ...  ...
# 666              60.305715              29.795000       46.223846  ...
# 667              71.933333              32.926471       51.210938  ...
# 668              71.964001              24.209285       52.300294  ...
# 669              85.526667              73.312001       79.097895  ...
# 670              71.190345              30.781923       52.088182  ...
#
#      RMSD_backbone_peptide  RMSD_all_atom_peptide  known_motif_plddt  DockQ  \
# 0                 0.325264               0.510364          90.693334  0.966
# 1                 0.335499               0.541225          88.134445  0.968
# 2                 0.359419               0.544323          79.068888  0.964
# 3                 0.373581               0.562924          80.512221  0.967
# 4                 0.375008               0.553687          74.640002  0.963
# ..                     ...                    ...                ...    ...
# 666              16.675762              16.607645          30.686000  0.095
# 667              19.187805              19.616602          32.162000  0.065
# 668              21.784376              22.200975          23.505000  0.053
# 669              28.551508              29.629011          19.876000  0.033
# 670              20.265190              20.449677          25.529000  0.059
#
#        iRMS    LRMS  Fnonnat         dmi_name  domain_ext_index  \
# 0     0.431   0.315    0.071       DEG_SIAH_1                 0
# 1     0.412   0.334    0.093       DEG_SIAH_1                 1
# 2     0.447   0.356    0.071       DEG_SIAH_1                 0
# 3     0.417   0.371    0.071       DEG_SIAH_1                 1
# 4     0.454   0.370    0.049       DEG_SIAH_1                 0
# ..      ...     ...      ...              ...               ...
# 666   7.554  16.711    0.857  LIG_CNOT1_NIM_1                 2
# 667   8.312  19.196    1.000  LIG_CNOT1_NIM_1                 0
# 668   8.990  21.843    1.000  LIG_CNOT1_NIM_1                 1
# 669  11.244  28.572    0.000  LIG_CNOT1_NIM_1                 2
# 670   8.788  20.268    1.000  LIG_CNOT1_NIM_1                 0
#
#      motif_ext_index
# 0                  2
# 1                  2
# 2                  4
# 3                  4
# 4                  3
# ..               ...
# 666                3
# 667                3
# 668                5
# 669                5
# 670                5
#
# [671 rows x 30 columns]

# %%
# make a copy of the final_df to work with
temp = final_df.copy()

# make a summary of the number of sample size in each extension step pairings
summary = temp.groupby(['domain_ext_index','motif_ext_index']).size().reset_index(name='size').pivot(index='motif_ext_index',
                                                                                              columns='domain_ext_index')

# fill 0x0 with the number of DMIs selected for extension
summary.iloc[0,0] = len(temp.dmi_name.unique())
summary = summary.astype('int')
summary
# Out:
#                  size
# domain_ext_index    0   1   2   3
# motif_ext_index
# 0                  34  34  22  19
# 1                  34  34  22  17
# 2                  34  34  22  17
# 3                  34  34  21  16
# 4                  33  33  21  15
# 5                  33  33  21  15
# 6                  26  25  13   9

# %%
final_df[final_df['model_id'] != 'Prediction failed'].shape
# Out:
# (671, 30)

# %% [markdown]
# ### After checking manually, we decided to exclude the following DMI types from extension analysis because of the following reason:
# - DEG_APCC_KENBOX: has a second known ELM instance (303AKENE307) that upon extension AF puts this motif instead to the interface.
# - LIG_Pex14_3: upon full length extension, an ELM instance from another ELM class LIG_Pex14_1 was put at the interface. The motif protein extended is P50542 (PEX5), and it has quite some ELM instances involved in Pex biology. The one put at the interface is 308WLSDY312 -> load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run46/run46_LIG_Pex14_3_MFL_DFL/ranked_2_superimpose.pse
# - LIG_GYF: We used the ELM annotated structure 1L2Z as the solved model for superimposition but it seems like ELM DB made a mistake in annotating it as region 281-289 of P06729 when it actually is region 295-303 of the same protein. This mistake is corrected when we manually annotated the minimal interacting region. Nonetheless, upon extension, AF sees region 281-289 and puts it at the interface instead. So I think the main problem is that these repeated occurrence of known motif is problematic to our extension analysis. -> load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run39/run39_LIG_GYF_M277_M321_D1_D341/ranked_1_superimpose.pse

# %%
# exclude the problematic DMI type and their extensions
print(final_df.shape)
excluded_dmi = ['DEG_APCC_KENBOX_2','LIG_Pex14_3','LIG_GYF']
final_df = final_df[final_df['dmi_name'].isin(['DEG_APCC_KENBOX_2','LIG_Pex14_3','LIG_GYF'])==False].copy()
print(final_df.shape)

# reset_index on final_df because I later use its index to remove prediction in this df that is not predicted in 
# run51
final_df.reset_index(drop=True,inplace=True)
# Out:
# (671, 30)
# (632, 30)

# %% [markdown]
# Check again the number of predictions that we still have in every motif-domain extension pair

# %%
# make a copy of the final_df to work with
temp = final_df.copy()

# make a summary of the number of sample size in each extension step pairings
summary = temp.groupby(['domain_ext_index','motif_ext_index']).size().reset_index(name='size').pivot(index='motif_ext_index',
                                                                                              columns='domain_ext_index')

# fill 0x0 with the number of DMIs selected for extension
summary.iloc[0,0] = len(temp.dmi_name.unique())
summary = summary.astype('int')
summary
# Out:
#                  size
# domain_ext_index    0   1   2   3
# motif_ext_index
# 0                  31  31  22  19
# 1                  31  31  22  17
# 2                  31  31  22  17
# 3                  31  31  21  16
# 4                  30  30  21  15
# 5                  30  30  21  15
# 6                  23  22  13   9

# %% [markdown]
# ### Retrieve minimal fragment information for analysis on how the extensions affect their prediction accuracy compared to minimal fragment predictions

# %%
def parse_prediction_name(prediction_name):
    """Parse out different components in the standard name for a minimal DMI prediction (e.g. run37_DEG_APCC_KENBOX_2_4GGD)

    Args:
        prediction_name (str): Name of the folder containing the AlphaFold predicted structure

    Returns:
        run_id (str): Run ID
        dmi_name (str): Name of DMI type
        pdb_id (str): PDB ID
    """
    splits = prediction_name.split('_')
    run_id = splits[0]
    dmi_name = '_'.join(splits[1:-1])
    pdb_id = splits[-1]
    return [run_id, dmi_name, pdb_id]

min_df = pd.read_csv('/Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run37/run37_template_indep_dep_info.tsv',
                sep='\t',index_col=0)

min_df[['run_id','dmi_name','pdb_id']] = min_df.apply(lambda x: parse_prediction_name(x['prediction_name']),
                                                                        axis=1,result_type='expand')
min_df = min_df[['dmi_name','RMSD_all_atom_peptide','DockQ','model_confidence','intf_avg_plddt',
                 'chainB_intf_avg_plddt','pDockQ','iPAE']].copy()
min_df = min_df.sort_values(['RMSD_all_atom_peptide'],ascending=True).drop_duplicates(subset=['dmi_name'],keep='first').copy()
print(min_df.shape)

# filter for only DMI types that are used for extensions
min_df = min_df[min_df['dmi_name'].isin(final_df.dmi_name.unique())].copy()
print(min_df.shape)
# Out:
# (136, 8)
# (31, 8)

# %%
condlist = [min_df['RMSD_all_atom_peptide'] <= 2,
           (min_df['RMSD_all_atom_peptide'] > 2) & (min_df['RMSD_all_atom_peptide'] <= 5),
            (min_df['RMSD_all_atom_peptide'] > 5) & (min_df['RMSD_all_atom_peptide'] <= 15),
            min_df['RMSD_all_atom_peptide'] > 15]
choicelist = ['correct_sidechain','correct_backbone','correct_pocket','wrong_pocket']
min_df['RMSD_all_atom_peptide_classification'] = np.select(condlist,choicelist)

min_df.groupby('RMSD_all_atom_peptide_classification').size()
# Out:
# RMSD_all_atom_peptide_classification
# correct_backbone      8
# correct_pocket       11
# correct_sidechain    12
# dtype: int64

# %%
# join RMSD_domain and RMSD_peptide with agg_min_df so that I can calculate the difference of RMSD after extension
merged_df = pd.merge(final_df, min_df, how='inner',on='dmi_name',suffixes=['','_min_frag'])

# calculate difference in peptide RMSD then the fold change
merged_df['RMSD_all_atom_peptide_fold_change'] = np.log2(merged_df['RMSD_all_atom_peptide_min_frag'] / merged_df['RMSD_all_atom_peptide'])

# calculate the change in DockQ after extension
merged_df['DockQ_ext-DockQ_min'] = merged_df['DockQ'] - merged_df['DockQ_min_frag']
merged_df
# Out:
#             project_name                            prediction_name run_id  \
# 0    AlphaFold_benchmark              run39_DEG_SIAH_1_M41_M85_Dmin  run39
# 1    AlphaFold_benchmark           run39_DEG_SIAH_1_M41_M85_D1_D282  run39
# 2    AlphaFold_benchmark              run39_DEG_SIAH_1_M5_M121_Dmin  run39
# 3    AlphaFold_benchmark           run39_DEG_SIAH_1_M5_M121_D1_D282  run39
# 4    AlphaFold_benchmark             run39_DEG_SIAH_1_M23_M103_Dmin  run39
# ..                   ...                                        ...    ...
# 627  AlphaFold_benchmark   run40_LIG_CNOT1_NIM_1_M1_M89_D1377_D2376  run40
# 628  AlphaFold_benchmark          run39_LIG_CNOT1_NIM_1_M1_M89_Dmin  run39
# 629  AlphaFold_benchmark  run40_LIG_CNOT1_NIM_1_M1_M276_D1544_D2376  run40
# 630  AlphaFold_benchmark  run40_LIG_CNOT1_NIM_1_M1_M276_D1377_D2376  run40
# 631  AlphaFold_benchmark         run39_LIG_CNOT1_NIM_1_M1_M276_Dmin  run39
#
#      chainA_length  chainB_length  model_id  model_confidence  \
# 0              188             45  ranked_2          0.749542
# 1              282             45  ranked_3          0.648164
# 2              188            117  ranked_2          0.638711
# 3              282            117  ranked_2          0.578105
# 4              188             81  ranked_2          0.651657
# ..             ...            ...       ...               ...
# 627           1000             89  ranked_2          0.250435
# 628            432             89  ranked_4          0.277345
# 629            833            276  ranked_3          0.249178
# 630           1000            276  ranked_0          0.298145
# 631            432            276  ranked_2          0.249707
#
#      chainA_intf_avg_plddt  chainB_intf_avg_plddt  intf_avg_plddt  ...  \
# 0                89.468124              61.922609       77.949091  ...
# 1                89.451112              56.308334       76.194001  ...
# 2                86.530357              67.089444       78.923043  ...
# 3                89.676072              70.348235       82.374444  ...
# 4                88.818000              63.364287       79.680769  ...
# ..                     ...                    ...             ...  ...
# 627              60.305715              29.795000       46.223846  ...
# 628              71.933333              32.926471       51.210938  ...
# 629              71.964001              24.209285       52.300294  ...
# 630              85.526667              73.312001       79.097895  ...
# 631              71.190345              30.781923       52.088182  ...
#
#      RMSD_all_atom_peptide_min_frag  DockQ_min_frag  \
# 0                          0.787199           0.959
# 1                          0.787199           0.959
# 2                          0.787199           0.959
# 3                          0.787199           0.959
# 4                          0.787199           0.959
# ..                              ...             ...
# 627                       14.618848           0.118
# 628                       14.618848           0.118
# 629                       14.618848           0.118
# 630                       14.618848           0.118
# 631                       14.618848           0.118
#
#      model_confidence_min_frag  intf_avg_plddt_min_frag  \
# 0                     0.920907                95.023548
# 1                     0.920907                95.023548
# 2                     0.920907                95.023548
# 3                     0.920907                95.023548
# 4                     0.920907                95.023548
# ..                         ...                      ...
# 627                   0.410193                55.482857
# 628                   0.410193                55.482857
# 629                   0.410193                55.482857
# 630                   0.410193                55.482857
# 631                   0.410193                55.482857
#
#      chainB_intf_avg_plddt_min_frag  pDockQ_min_frag  iPAE_min_frag  \
# 0                         92.233334         0.463805       1.807006
# 1                         92.233334         0.463805       1.807006
# 2                         92.233334         0.463805       1.807006
# 3                         92.233334         0.463805       1.807006
# 4                         92.233334         0.463805       1.807006
# ..                              ...              ...            ...
# 627                       28.097143         0.023889      19.094448
# 628                       28.097143         0.023889      19.094448
# 629                       28.097143         0.023889      19.094448
# 630                       28.097143         0.023889      19.094448
# 631                       28.097143         0.023889      19.094448
#
#      RMSD_all_atom_peptide_classification  RMSD_all_atom_peptide_fold_change  \
# 0                       correct_sidechain                           0.625203
# 1                       correct_sidechain                           0.540500
# 2                       correct_sidechain                           0.532265
# 3                       correct_sidechain                           0.483788
# 4                       correct_sidechain                           0.507659
# ..                                    ...                                ...
# 627                        correct_pocket                          -0.184018
# 628                        correct_pocket                          -0.424246
# 629                        correct_pocket                          -0.602793
# 630                        correct_pocket                          -1.019181
# 631                        correct_pocket                          -0.484248
#
#      DockQ_ext-DockQ_min
# 0                  0.007
# 1                  0.009
# 2                  0.005
# 3                  0.008
# 4                  0.004
# ..                   ...
# 627               -0.023
# 628               -0.053
# 629               -0.065
# 630               -0.085
# 631               -0.059
#
# [632 rows x 40 columns]

# %%
# classify the RMSD peptide before extension (minimal)
condlist = [merged_df['RMSD_all_atom_peptide_min_frag'] <= 2,
           (merged_df['RMSD_all_atom_peptide_min_frag'] > 2) & (merged_df['RMSD_all_atom_peptide_min_frag'] <= 5),
            (merged_df['RMSD_all_atom_peptide_min_frag'] > 5) & (merged_df['RMSD_all_atom_peptide_min_frag'] <= 15),
            merged_df['RMSD_all_atom_peptide_min_frag'] > 15]
choicelist = ['correct_sidechain','correct_backbone','correct_pocket','wrong_pocket']
merged_df['RMSD_all_atom_peptide_classification_min_frag'] = np.select(condlist,choicelist)

merged_df
# Out:
#             project_name                            prediction_name run_id  \
# 0    AlphaFold_benchmark              run39_DEG_SIAH_1_M41_M85_Dmin  run39
# 1    AlphaFold_benchmark           run39_DEG_SIAH_1_M41_M85_D1_D282  run39
# 2    AlphaFold_benchmark              run39_DEG_SIAH_1_M5_M121_Dmin  run39
# 3    AlphaFold_benchmark           run39_DEG_SIAH_1_M5_M121_D1_D282  run39
# 4    AlphaFold_benchmark             run39_DEG_SIAH_1_M23_M103_Dmin  run39
# ..                   ...                                        ...    ...
# 627  AlphaFold_benchmark   run40_LIG_CNOT1_NIM_1_M1_M89_D1377_D2376  run40
# 628  AlphaFold_benchmark          run39_LIG_CNOT1_NIM_1_M1_M89_Dmin  run39
# 629  AlphaFold_benchmark  run40_LIG_CNOT1_NIM_1_M1_M276_D1544_D2376  run40
# 630  AlphaFold_benchmark  run40_LIG_CNOT1_NIM_1_M1_M276_D1377_D2376  run40
# 631  AlphaFold_benchmark         run39_LIG_CNOT1_NIM_1_M1_M276_Dmin  run39
#
#      chainA_length  chainB_length  model_id  model_confidence  \
# 0              188             45  ranked_2          0.749542
# 1              282             45  ranked_3          0.648164
# 2              188            117  ranked_2          0.638711
# 3              282            117  ranked_2          0.578105
# 4              188             81  ranked_2          0.651657
# ..             ...            ...       ...               ...
# 627           1000             89  ranked_2          0.250435
# 628            432             89  ranked_4          0.277345
# 629            833            276  ranked_3          0.249178
# 630           1000            276  ranked_0          0.298145
# 631            432            276  ranked_2          0.249707
#
#      chainA_intf_avg_plddt  chainB_intf_avg_plddt  intf_avg_plddt  ...  \
# 0                89.468124              61.922609       77.949091  ...
# 1                89.451112              56.308334       76.194001  ...
# 2                86.530357              67.089444       78.923043  ...
# 3                89.676072              70.348235       82.374444  ...
# 4                88.818000              63.364287       79.680769  ...
# ..                     ...                    ...             ...  ...
# 627              60.305715              29.795000       46.223846  ...
# 628              71.933333              32.926471       51.210938  ...
# 629              71.964001              24.209285       52.300294  ...
# 630              85.526667              73.312001       79.097895  ...
# 631              71.190345              30.781923       52.088182  ...
#
#      DockQ_min_frag  model_confidence_min_frag  intf_avg_plddt_min_frag  \
# 0             0.959                   0.920907                95.023548
# 1             0.959                   0.920907                95.023548
# 2             0.959                   0.920907                95.023548
# 3             0.959                   0.920907                95.023548
# 4             0.959                   0.920907                95.023548
# ..              ...                        ...                      ...
# 627           0.118                   0.410193                55.482857
# 628           0.118                   0.410193                55.482857
# 629           0.118                   0.410193                55.482857
# 630           0.118                   0.410193                55.482857
# 631           0.118                   0.410193                55.482857
#
#      chainB_intf_avg_plddt_min_frag  pDockQ_min_frag  iPAE_min_frag  \
# 0                         92.233334         0.463805       1.807006
# 1                         92.233334         0.463805       1.807006
# 2                         92.233334         0.463805       1.807006
# 3                         92.233334         0.463805       1.807006
# 4                         92.233334         0.463805       1.807006
# ..                              ...              ...            ...
# 627                       28.097143         0.023889      19.094448
# 628                       28.097143         0.023889      19.094448
# 629                       28.097143         0.023889      19.094448
# 630                       28.097143         0.023889      19.094448
# 631                       28.097143         0.023889      19.094448
#
#      RMSD_all_atom_peptide_classification  RMSD_all_atom_peptide_fold_change  \
# 0                       correct_sidechain                           0.625203
# 1                       correct_sidechain                           0.540500
# 2                       correct_sidechain                           0.532265
# 3                       correct_sidechain                           0.483788
# 4                       correct_sidechain                           0.507659
# ..                                    ...                                ...
# 627                        correct_pocket                          -0.184018
# 628                        correct_pocket                          -0.424246
# 629                        correct_pocket                          -0.602793
# 630                        correct_pocket                          -1.019181
# 631                        correct_pocket                          -0.484248
#
#      DockQ_ext-DockQ_min  RMSD_all_atom_peptide_classification_min_frag
# 0                  0.007                              correct_sidechain
# 1                  0.009                              correct_sidechain
# 2                  0.005                              correct_sidechain
# 3                  0.008                              correct_sidechain
# 4                  0.004                              correct_sidechain
# ..                   ...                                            ...
# 627               -0.023                                 correct_pocket
# 628               -0.053                                 correct_pocket
# 629               -0.065                                 correct_pocket
# 630               -0.085                                 correct_pocket
# 631               -0.059                                 correct_pocket
#
# [632 rows x 41 columns]

# %%
# classify the RMSD peptide before extension (minimal)
condlist = [merged_df['RMSD_all_atom_peptide'] <= 2,
           (merged_df['RMSD_all_atom_peptide'] > 2) & (merged_df['RMSD_all_atom_peptide'] <= 5),
            (merged_df['RMSD_all_atom_peptide'] > 5) & (merged_df['RMSD_all_atom_peptide'] <= 15),
            merged_df['RMSD_all_atom_peptide'] > 15]
choicelist = ['correct_sidechain','correct_backbone','correct_pocket','wrong_pocket']
merged_df['RMSD_all_atom_peptide_classification'] = np.select(condlist,choicelist)

merged_df
# Out:
#             project_name                            prediction_name run_id  \
# 0    AlphaFold_benchmark              run39_DEG_SIAH_1_M41_M85_Dmin  run39
# 1    AlphaFold_benchmark           run39_DEG_SIAH_1_M41_M85_D1_D282  run39
# 2    AlphaFold_benchmark              run39_DEG_SIAH_1_M5_M121_Dmin  run39
# 3    AlphaFold_benchmark           run39_DEG_SIAH_1_M5_M121_D1_D282  run39
# 4    AlphaFold_benchmark             run39_DEG_SIAH_1_M23_M103_Dmin  run39
# ..                   ...                                        ...    ...
# 627  AlphaFold_benchmark   run40_LIG_CNOT1_NIM_1_M1_M89_D1377_D2376  run40
# 628  AlphaFold_benchmark          run39_LIG_CNOT1_NIM_1_M1_M89_Dmin  run39
# 629  AlphaFold_benchmark  run40_LIG_CNOT1_NIM_1_M1_M276_D1544_D2376  run40
# 630  AlphaFold_benchmark  run40_LIG_CNOT1_NIM_1_M1_M276_D1377_D2376  run40
# 631  AlphaFold_benchmark         run39_LIG_CNOT1_NIM_1_M1_M276_Dmin  run39
#
#      chainA_length  chainB_length  model_id  model_confidence  \
# 0              188             45  ranked_2          0.749542
# 1              282             45  ranked_3          0.648164
# 2              188            117  ranked_2          0.638711
# 3              282            117  ranked_2          0.578105
# 4              188             81  ranked_2          0.651657
# ..             ...            ...       ...               ...
# 627           1000             89  ranked_2          0.250435
# 628            432             89  ranked_4          0.277345
# 629            833            276  ranked_3          0.249178
# 630           1000            276  ranked_0          0.298145
# 631            432            276  ranked_2          0.249707
#
#      chainA_intf_avg_plddt  chainB_intf_avg_plddt  intf_avg_plddt  ...  \
# 0                89.468124              61.922609       77.949091  ...
# 1                89.451112              56.308334       76.194001  ...
# 2                86.530357              67.089444       78.923043  ...
# 3                89.676072              70.348235       82.374444  ...
# 4                88.818000              63.364287       79.680769  ...
# ..                     ...                    ...             ...  ...
# 627              60.305715              29.795000       46.223846  ...
# 628              71.933333              32.926471       51.210938  ...
# 629              71.964001              24.209285       52.300294  ...
# 630              85.526667              73.312001       79.097895  ...
# 631              71.190345              30.781923       52.088182  ...
#
#      DockQ_min_frag  model_confidence_min_frag  intf_avg_plddt_min_frag  \
# 0             0.959                   0.920907                95.023548
# 1             0.959                   0.920907                95.023548
# 2             0.959                   0.920907                95.023548
# 3             0.959                   0.920907                95.023548
# 4             0.959                   0.920907                95.023548
# ..              ...                        ...                      ...
# 627           0.118                   0.410193                55.482857
# 628           0.118                   0.410193                55.482857
# 629           0.118                   0.410193                55.482857
# 630           0.118                   0.410193                55.482857
# 631           0.118                   0.410193                55.482857
#
#      chainB_intf_avg_plddt_min_frag  pDockQ_min_frag  iPAE_min_frag  \
# 0                         92.233334         0.463805       1.807006
# 1                         92.233334         0.463805       1.807006
# 2                         92.233334         0.463805       1.807006
# 3                         92.233334         0.463805       1.807006
# 4                         92.233334         0.463805       1.807006
# ..                              ...              ...            ...
# 627                       28.097143         0.023889      19.094448
# 628                       28.097143         0.023889      19.094448
# 629                       28.097143         0.023889      19.094448
# 630                       28.097143         0.023889      19.094448
# 631                       28.097143         0.023889      19.094448
#
#      RMSD_all_atom_peptide_classification  RMSD_all_atom_peptide_fold_change  \
# 0                       correct_sidechain                           0.625203
# 1                       correct_sidechain                           0.540500
# 2                       correct_sidechain                           0.532265
# 3                       correct_sidechain                           0.483788
# 4                       correct_sidechain                           0.507659
# ..                                    ...                                ...
# 627                          wrong_pocket                          -0.184018
# 628                          wrong_pocket                          -0.424246
# 629                          wrong_pocket                          -0.602793
# 630                          wrong_pocket                          -1.019181
# 631                          wrong_pocket                          -0.484248
#
#      DockQ_ext-DockQ_min  RMSD_all_atom_peptide_classification_min_frag
# 0                  0.007                              correct_sidechain
# 1                  0.009                              correct_sidechain
# 2                  0.005                              correct_sidechain
# 3                  0.008                              correct_sidechain
# 4                  0.004                              correct_sidechain
# ..                   ...                                            ...
# 627               -0.023                                 correct_pocket
# 628               -0.053                                 correct_pocket
# 629               -0.065                                 correct_pocket
# 630               -0.085                                 correct_pocket
# 631               -0.059                                 correct_pocket
#
# [632 rows x 41 columns]

# %% [markdown]
# ----
# ### Finished pre-processing and prediction checking, start analyzing benchmark metrics

# %%
# pivot the table for heatmap plotting
temp = merged_df[['domain_ext_index','motif_ext_index','RMSD_all_atom_peptide_fold_change']].pivot_table(index='motif_ext_index',
                                                                                   columns='domain_ext_index',
                                                                                   values='RMSD_all_atom_peptide_fold_change',
                                                                                   aggfunc=np.mean).fillna(0).copy()

fig, ax = plt.subplots(figsize=(4,4))
sns.heatmap(temp,annot=True,center=0,cmap=sns.diverging_palette(250, 18, as_cmap=True),vmin=-2.5,vmax=0.5,
           cbar_kws={'label': 'log$_{\mathrm{2}}$(RMSD$_{\mathrm{min}}$/RMSD$_{\mathrm{ext}}$)'})
plt.ylabel('Motif extension step',fontsize=global_fontsize)
plt.xlabel('Domain extension step',fontsize=global_fontsize)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=global_fontsize)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=global_fontsize)
plt.title('AF-MM v2.2',fontsize=global_fontsize)

plt.savefig(f'{save_path}domain_motif_ext_peptide_fold_change_heatmap_annot.pdf',transparent=True,
           bbox_inches='tight')
plt.savefig(f'{save_path}domain_motif_ext_peptide_fold_change_heatmap_annot.jpeg',transparent=True,dpi=300,
           bbox_inches='tight')
plt.show()

fig, ax = plt.subplots(figsize=(4,4))
sns.heatmap(temp,annot=False,center=0,cmap=sns.diverging_palette(250, 18, as_cmap=True),vmin=-2.5,vmax=0.5,
           cbar_kws={'label': 'log$_{\mathrm{2}}$(RMSD$_{\mathrm{min}}$/RMSD$_{\mathrm{ext}}$)'})
plt.ylabel('Motif extension step',fontsize=global_fontsize)
plt.xlabel('Domain extension step',fontsize=global_fontsize)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=global_fontsize)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=global_fontsize)
plt.title('AF-MM v2.2',fontsize=global_fontsize)

plt.savefig(f'{save_path}domain_motif_ext_peptide_fold_change_heatmap.pdf',transparent=True,
           bbox_inches='tight')
plt.savefig(f'{save_path}domain_motif_ext_peptide_fold_change_heatmap.jpeg',transparent=True,dpi=300,
           bbox_inches='tight')
plt.show()

# %%
# pivot the table for heatmap plotting
temp = merged_df[['domain_ext_index','motif_ext_index','DockQ_ext-DockQ_min']].pivot_table(index='motif_ext_index',
                                                                                   columns='domain_ext_index',
                                                                                   values='DockQ_ext-DockQ_min',
                                                                                   aggfunc=np.mean).fillna(0).copy()

fig, ax = plt.subplots(figsize=(4,4))
sns.heatmap(temp,annot=False,center=0,cmap=sns.diverging_palette(250, 18, as_cmap=True),vmin=-0.36,vmax=0.06,
           cbar_kws={'label': "DockQ$_{\mathrm{ext}}$ - DockQ$_{\mathrm{min}}$"})
plt.ylabel('Motif extension step',fontsize=global_fontsize)
plt.xlabel('Domain extension step',fontsize=global_fontsize)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=global_fontsize)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=global_fontsize)
plt.title('AF-MM v2.2',fontsize=global_fontsize)

plt.savefig(f'{save_path}DockQ_ext-DockQ_min_heatmap.pdf',transparent=True,
           bbox_inches='tight')
plt.savefig(f'{save_path}DockQ_ext-DockQ_min_heatmap.jpeg',transparent=True,dpi=300,
           bbox_inches='tight')
plt.show()

fig, ax = plt.subplots(figsize=(4,4))
sns.heatmap(temp,annot=True,center=0,cmap=sns.diverging_palette(250, 18, as_cmap=True),vmin=-0.36,vmax=0.06,
           cbar_kws={'label': "DockQ$_{\mathrm{ext}}$ - DockQ$_{\mathrm{min}}$"})
plt.ylabel('Motif extension step',fontsize=global_fontsize)
plt.xlabel('Domain extension step',fontsize=global_fontsize)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=global_fontsize)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=global_fontsize)
plt.title('AF-MM v2.2',fontsize=global_fontsize)

plt.savefig(f'{save_path}DockQ_ext-DockQ_min_heatmap_annot.pdf',transparent=True,
           bbox_inches='tight')
plt.savefig(f'{save_path}DockQ_ext-DockQ_min_heatmap_annot.jpeg',transparent=True,dpi=300,
           bbox_inches='tight')
plt.show()

# %%
# pivot the table for heatmap plotting
temp = merged_df[['domain_ext_index','motif_ext_index','model_confidence']].pivot_table(index='motif_ext_index',
                                                                                   columns='domain_ext_index',
                                                                                   values='model_confidence',
                                                                                   aggfunc=np.mean).copy()

# calculate the value to fill for 0 x 0 extension
temp.fillna(np.mean(min_df.model_confidence),inplace=True)

fig, ax = plt.subplots(figsize=(4,4))
sns.heatmap(temp,annot=False,cmap=sns.color_palette("Reds", as_cmap=True),vmin=0.3,vmax=0.9,
           cbar_kws={'label': 'Average model confidence'})
plt.ylabel('Motif extension step',fontsize=global_fontsize)
plt.xlabel('Domain extension step',fontsize=global_fontsize)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=global_fontsize)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=global_fontsize)
plt.title('AF-MM v2.2',fontsize=global_fontsize)

plt.savefig(f'{save_path}domain_motif_ext_model_confidence_heatmap.pdf',transparent=True,
           bbox_inches='tight')
plt.savefig(f'{save_path}domain_motif_ext_model_confidence_heatmap.jpeg',transparent=True,dpi=300,
           bbox_inches='tight')
plt.show()

fig, ax = plt.subplots(figsize=(4,4))
sns.heatmap(temp,annot=True,cmap=sns.color_palette("Reds", as_cmap=True),vmin=0.3,vmax=0.9,
           cbar_kws={'label': 'Average model confidence'})
plt.ylabel('Motif extension step',fontsize=global_fontsize)
plt.xlabel('Domain extension step',fontsize=global_fontsize)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=global_fontsize)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=global_fontsize)
plt.title('AF-MM v2.2',fontsize=global_fontsize)

plt.savefig(f'{save_path}domain_motif_ext_model_confidence_heatmap_annot.pdf',transparent=True,
           bbox_inches='tight')
plt.savefig(f'{save_path}domain_motif_ext_model_confidence_heatmap_annot.jpeg',transparent=True,dpi=300,
           bbox_inches='tight')
plt.show()

# %%
# pivot the table for heatmap plotting
temp = merged_df[['domain_ext_index','motif_ext_index','chainB_intf_avg_plddt']].pivot_table(index='motif_ext_index',
                                                                                   columns='domain_ext_index',
                                                                                   values='chainB_intf_avg_plddt',
                                                                                   aggfunc=np.mean).copy()

# calculate the value to fill for 0 x 0 extension
temp.fillna(np.mean(min_df.intf_avg_plddt),inplace=True)

fig, ax = plt.subplots(figsize=(4,4))
sns.heatmap(temp,annot=False,cmap=sns.color_palette("Reds", as_cmap=True),vmin=50,vmax=90,
           cbar_kws={'ticks':[50,60,70,80,90],'label': 'Average motif chain interface pLDDT'})
plt.ylabel('Motif extension step',fontsize=global_fontsize)
plt.xlabel('Domain extension step',fontsize=global_fontsize)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=global_fontsize)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=global_fontsize)
plt.title('AF-MM v2.2',fontsize=global_fontsize)

plt.savefig(f'{save_path}domain_motif_ext_chainB_intf_avg_plddt_heatmap.pdf',transparent=True,
           bbox_inches='tight')
plt.savefig(f'{save_path}domain_motif_ext_chainB_intf_avg_plddt_heatmap.jpeg',transparent=True,dpi=300,
           bbox_inches='tight')
plt.show()

fig, ax = plt.subplots(figsize=(4,4))
sns.heatmap(temp,annot=True,cmap=sns.color_palette("Reds", as_cmap=True),vmin=50,vmax=90,
           cbar_kws={'ticks':[50,60,70,80,90],'label': 'Motif chain interface pLDDT'})
plt.ylabel('Motif extension step',fontsize=global_fontsize)
plt.xlabel('Domain extension step',fontsize=global_fontsize)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=global_fontsize)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=global_fontsize)
plt.title('AF-MM v2.2',fontsize=global_fontsize)

plt.savefig(f'{save_path}domain_motif_ext_chainB_intf_avg_plddt_heatmap_annot.pdf',transparent=True,
           bbox_inches='tight')
plt.savefig(f'{save_path}domain_motif_ext_chainB_intf_avg_plddt_heatmap_annot.jpeg',transparent=True,dpi=300,
           bbox_inches='tight')
plt.show()

# %%
# pivot the table for heatmap plotting
temp = merged_df[['domain_ext_index','motif_ext_index','pDockQ']].pivot_table(index='motif_ext_index',
                                                                                   columns='domain_ext_index',
                                                                                   values='pDockQ',
                                                                                   aggfunc=np.mean).copy()

# calculate the value to fill for 0 x 0 extension
temp.fillna(np.mean(min_df.pDockQ),inplace=True)

fig, ax = plt.subplots(figsize=(4,4))
sns.heatmap(temp,annot=False,cmap=sns.color_palette("Reds", as_cmap=True),vmin=0.0,vmax=0.3,
           cbar_kws={'label': 'Average pDockQ'})
plt.ylabel('Motif extension step',fontsize=global_fontsize)
plt.xlabel('Domain extension step',fontsize=global_fontsize)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=global_fontsize)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=global_fontsize)
plt.title('AF-MM v2.2',fontsize=global_fontsize)

plt.savefig(f'{save_path}domain_motif_ext_pDockQ_heatmap.pdf',transparent=True,
           bbox_inches='tight')
plt.savefig(f'{save_path}domain_motif_ext_pDockQ_heatmap.jpeg',transparent=True,dpi=300,
           bbox_inches='tight')
plt.show()

fig, ax = plt.subplots(figsize=(4,4))
sns.heatmap(temp,annot=True,cmap=sns.color_palette("Reds", as_cmap=True),vmin=0.0,vmax=0.3,
           cbar_kws={'label': 'Average pDockQ'})
plt.ylabel('Motif extension step',fontsize=global_fontsize)
plt.xlabel('Domain extension step',fontsize=global_fontsize)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=global_fontsize)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=global_fontsize)
plt.title('AF-MM v2.2',fontsize=global_fontsize)

plt.savefig(f'{save_path}domain_motif_ext_pDockQ_heatmap_annot.pdf',transparent=True,
           bbox_inches='tight')
plt.savefig(f'{save_path}domain_motif_ext_pDockQ_heatmap_annot.jpeg',transparent=True,dpi=300,
           bbox_inches='tight')
plt.show()

# %%
# pivot the table for heatmap plotting
temp = merged_df[['domain_ext_index','motif_ext_index','iPAE']].pivot_table(index='motif_ext_index',
                                                                                   columns='domain_ext_index',
                                                                                   values='iPAE',
                                                                                   aggfunc=np.mean).copy()

# calculate the value to fill for 0 x 0 extension
temp.fillna(np.mean(min_df.iPAE),inplace=True)

fig, ax = plt.subplots(figsize=(4,4))
sns.heatmap(temp,annot=False,cmap=sns.color_palette("Reds", as_cmap=True),vmin=4,vmax=24,
           cbar_kws={'label': 'Average iPAE'})
plt.ylabel('Motif extension step',fontsize=global_fontsize)
plt.xlabel('Domain extension step',fontsize=global_fontsize)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=global_fontsize)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=global_fontsize)
plt.title('AF-MM v2.2',fontsize=global_fontsize)

plt.savefig(f'{save_path}domain_motif_ext_iPAE_heatmap.pdf',transparent=True,
           bbox_inches='tight')
plt.savefig(f'{save_path}domain_motif_ext_iPAE_heatmap.jpeg',transparent=True,dpi=300,
           bbox_inches='tight')
plt.show()

fig, ax = plt.subplots(figsize=(4,4))
sns.heatmap(temp,annot=True,cmap=sns.color_palette("Reds", as_cmap=True),vmin=4,vmax=24,
           cbar_kws={'label': 'Average iPAE'})
plt.ylabel('Motif extension step',fontsize=global_fontsize)
plt.xlabel('Domain extension step',fontsize=global_fontsize)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=global_fontsize)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=global_fontsize)
plt.title('AF-MM v2.2',fontsize=global_fontsize)

plt.savefig(f'{save_path}domain_motif_ext_iPAE_heatmap_annot.pdf',transparent=True,
           bbox_inches='tight')
plt.savefig(f'{save_path}domain_motif_ext_iPAE_heatmap_annot.jpeg',transparent=True,dpi=300,
           bbox_inches='tight')
plt.show()

# %%
merged_df
# Out:
#             project_name                            prediction_name run_id  \
# 0    AlphaFold_benchmark              run39_DEG_SIAH_1_M41_M85_Dmin  run39
# 1    AlphaFold_benchmark           run39_DEG_SIAH_1_M41_M85_D1_D282  run39
# 2    AlphaFold_benchmark              run39_DEG_SIAH_1_M5_M121_Dmin  run39
# 3    AlphaFold_benchmark           run39_DEG_SIAH_1_M5_M121_D1_D282  run39
# 4    AlphaFold_benchmark             run39_DEG_SIAH_1_M23_M103_Dmin  run39
# ..                   ...                                        ...    ...
# 627  AlphaFold_benchmark   run40_LIG_CNOT1_NIM_1_M1_M89_D1377_D2376  run40
# 628  AlphaFold_benchmark          run39_LIG_CNOT1_NIM_1_M1_M89_Dmin  run39
# 629  AlphaFold_benchmark  run40_LIG_CNOT1_NIM_1_M1_M276_D1544_D2376  run40
# 630  AlphaFold_benchmark  run40_LIG_CNOT1_NIM_1_M1_M276_D1377_D2376  run40
# 631  AlphaFold_benchmark         run39_LIG_CNOT1_NIM_1_M1_M276_Dmin  run39
#
#      chainA_length  chainB_length  model_id  model_confidence  \
# 0              188             45  ranked_2          0.749542
# 1              282             45  ranked_3          0.648164
# 2              188            117  ranked_2          0.638711
# 3              282            117  ranked_2          0.578105
# 4              188             81  ranked_2          0.651657
# ..             ...            ...       ...               ...
# 627           1000             89  ranked_2          0.250435
# 628            432             89  ranked_4          0.277345
# 629            833            276  ranked_3          0.249178
# 630           1000            276  ranked_0          0.298145
# 631            432            276  ranked_2          0.249707
#
#      chainA_intf_avg_plddt  chainB_intf_avg_plddt  intf_avg_plddt  ...  \
# 0                89.468124              61.922609       77.949091  ...
# 1                89.451112              56.308334       76.194001  ...
# 2                86.530357              67.089444       78.923043  ...
# 3                89.676072              70.348235       82.374444  ...
# 4                88.818000              63.364287       79.680769  ...
# ..                     ...                    ...             ...  ...
# 627              60.305715              29.795000       46.223846  ...
# 628              71.933333              32.926471       51.210938  ...
# 629              71.964001              24.209285       52.300294  ...
# 630              85.526667              73.312001       79.097895  ...
# 631              71.190345              30.781923       52.088182  ...
#
#      DockQ_min_frag  model_confidence_min_frag  intf_avg_plddt_min_frag  \
# 0             0.959                   0.920907                95.023548
# 1             0.959                   0.920907                95.023548
# 2             0.959                   0.920907                95.023548
# 3             0.959                   0.920907                95.023548
# 4             0.959                   0.920907                95.023548
# ..              ...                        ...                      ...
# 627           0.118                   0.410193                55.482857
# 628           0.118                   0.410193                55.482857
# 629           0.118                   0.410193                55.482857
# 630           0.118                   0.410193                55.482857
# 631           0.118                   0.410193                55.482857
#
#      chainB_intf_avg_plddt_min_frag  pDockQ_min_frag  iPAE_min_frag  \
# 0                         92.233334         0.463805       1.807006
# 1                         92.233334         0.463805       1.807006
# 2                         92.233334         0.463805       1.807006
# 3                         92.233334         0.463805       1.807006
# 4                         92.233334         0.463805       1.807006
# ..                              ...              ...            ...
# 627                       28.097143         0.023889      19.094448
# 628                       28.097143         0.023889      19.094448
# 629                       28.097143         0.023889      19.094448
# 630                       28.097143         0.023889      19.094448
# 631                       28.097143         0.023889      19.094448
#
#      RMSD_all_atom_peptide_classification  RMSD_all_atom_peptide_fold_change  \
# 0                       correct_sidechain                           0.625203
# 1                       correct_sidechain                           0.540500
# 2                       correct_sidechain                           0.532265
# 3                       correct_sidechain                           0.483788
# 4                       correct_sidechain                           0.507659
# ..                                    ...                                ...
# 627                          wrong_pocket                          -0.184018
# 628                          wrong_pocket                          -0.424246
# 629                          wrong_pocket                          -0.602793
# 630                          wrong_pocket                          -1.019181
# 631                          wrong_pocket                          -0.484248
#
#      DockQ_ext-DockQ_min  RMSD_all_atom_peptide_classification_min_frag
# 0                  0.007                              correct_sidechain
# 1                  0.009                              correct_sidechain
# 2                  0.005                              correct_sidechain
# 3                  0.008                              correct_sidechain
# 4                  0.004                              correct_sidechain
# ..                   ...                                            ...
# 627               -0.023                                 correct_pocket
# 628               -0.053                                 correct_pocket
# 629               -0.065                                 correct_pocket
# 630               -0.085                                 correct_pocket
# 631               -0.059                                 correct_pocket
#
# [632 rows x 41 columns]

# %%
# export the dataframe used for plotting for publication's supplemental table
temp = merged_df.copy()
temp['prediction_name'] = [pred_name.lstrip(f'{run_id}_') for pred_name, run_id in zip(temp['prediction_name'],
                                                                                temp['run_id'])]
print(temp.shape)
# temp.to_csv('/Volumes/imb-luckgr/manuscripts/AlphaFold_paper/tables/MMv2.2_extended_DMI_prediction_raw.tsv',
#          sep='\t',index=None)
# Out:
# (632, 41)

# %% [markdown]
# ----
# ### Due to AlphaFold failing to predict some data points in MMv2.3, I would like to also make the same set of plots but with only data points that are successfully predicted in MMv2.3, so that I can compare between the trend of MMv2.2 to MMv2.3.

# %%
# use dmi_name and chain A, B length to find predictions that are successful for both v2.2 and v2.3
def parse_prediction_name(prediction_name,DMI_name_list):
    """Parse out different components in the standard name for a minimal DMI prediction (e.g. run51_DEG_APCC_KENBOX_2_MFL_DFL)

    Args:
        prediction_name (str): Name of the folder containing the AlphaFold predicted structure
        DMI_name_list (list of str): A list of DMI types

    Returns:
        run_id (str): Run ID
        dmi_name (str): Name of DMI type
        seq_annot (str): start and end of the extended model (e.g. M31_M45_Dmin)
    """
    splits = prediction_name.split('_')
    run_id = splits[0]
    temp = '_'.join(splits[1:])
    for dmi_name in DMI_name_list:
        match = re.search(dmi_name,temp)
        if match is not None:
            seq_annot = temp[match.end()+1:]
            return [run_id, dmi_name]
        
query = f"""select * from chopyan_db.AlphaFold_prediction_result
where run_id in ('run51') and project_name = 'AlphaFold_benchmark'"""

run51 = pd.read_sql_query(query,con=con)

run51[['run_id','dmi_name']] = run51.apply(lambda x: parse_prediction_name(x['prediction_name'],dmi_types),
                                            axis=1,result_type='expand')
run51
# Out:
#              project_name                          prediction_name run_id  \
# 0     AlphaFold_benchmark  run51_DEG_APCC_KENBOX_2_M15_M39_D1_D499  run51
# 1     AlphaFold_benchmark  run51_DEG_APCC_KENBOX_2_M15_M39_D1_D499  run51
# 2     AlphaFold_benchmark  run51_DEG_APCC_KENBOX_2_M15_M39_D1_D499  run51
# 3     AlphaFold_benchmark  run51_DEG_APCC_KENBOX_2_M15_M39_D1_D499  run51
# 4     AlphaFold_benchmark  run51_DEG_APCC_KENBOX_2_M15_M39_D1_D499  run51
# ...                   ...                                      ...    ...
# 3446  AlphaFold_benchmark       run51_TRG_AP2beta_CARGO_1_Mmin_DFL  run51
# 3447  AlphaFold_benchmark       run51_TRG_AP2beta_CARGO_1_Mmin_DFL  run51
# 3448  AlphaFold_benchmark       run51_TRG_AP2beta_CARGO_1_Mmin_DFL  run51
# 3449  AlphaFold_benchmark       run51_TRG_AP2beta_CARGO_1_Mmin_DFL  run51
# 3450  AlphaFold_benchmark       run51_TRG_AP2beta_CARGO_1_Mmin_DFL  run51
#
#       chainA_length  chainB_length  model_id  model_confidence  \
# 0               499             25  ranked_0          0.693907
# 1               499             25  ranked_1          0.690820
# 2               499             25  ranked_2          0.685654
# 3               499             25  ranked_3          0.678514
# 4               499             25  ranked_4          0.652961
# ...             ...            ...       ...               ...
# 3446            937             11  ranked_0          0.854484
# 3447            937             11  ranked_1          0.817379
# 3448            937             11  ranked_2          0.803851
# 3449            937             11  ranked_3          0.745026
# 3450            937             11  ranked_4          0.612363
#
#       chainA_intf_avg_plddt  chainB_intf_avg_plddt  intf_avg_plddt  ...  \
# 0                 97.205000              87.086999       93.591428  ...
# 1                 97.127778              86.359001       93.281786  ...
# 2                 96.652727              79.507000       91.294688  ...
# 3                 96.778333              82.695000       91.748571  ...
# 4                 96.299999              78.545000       89.958928  ...
# ...                     ...                    ...             ...  ...
# 3446              92.240666              78.001111       86.900833  ...
# 3447              88.862857              67.481111       80.496087  ...
# 3448              90.937334              69.568748       83.504783  ...
# 3449              89.183125              50.857500       76.407917  ...
# 3450              74.427693              30.092500       57.538096  ...
#
#       align_score_domain num_align_resi_domain  RMSD_backbone_peptide  \
# 0                 1681.0                 312.0               0.624025
# 1                 1681.0                 312.0               0.539758
# 2                 1681.0                 312.0               0.596557
# 3                 1681.0                 312.0               0.612031
# 4                 1681.0                 312.0               0.597260
# ...                  ...                   ...                    ...
# 3446              1224.0                 233.0               0.552314
# 3447              1224.0                 233.0               0.961719
# 3448              1224.0                 233.0               0.680285
# 3449              1224.0                 233.0               0.850946
# 3450              1224.0                 233.0              47.002151
#
#       RMSD_all_atom_peptide  known_motif_plddt  DockQ    iRMS    LRMS  \
# 0                  0.863402          94.356000  0.961   0.422   0.580
# 1                  0.830100          93.568001  0.955   0.363   0.509
# 2                  0.806905          93.240001  0.971   0.448   0.574
# 3                  0.788664          92.050000  0.965   0.385   0.569
# 4                  0.798899          90.378000  0.972   0.314   0.563
# ...                     ...                ...    ...     ...     ...
# 3446               1.355807          78.121819  0.956   0.387   0.578
# 3447               1.611342          67.528182  0.943   0.378   1.007
# 3448               1.463675          68.840908  0.947   0.366   0.721
# 3449               1.558591          50.104545  0.917   0.533   0.824
# 3450              47.587631          30.438182  0.013  16.243  47.130
#
#       Fnonnat             dmi_name
# 0       0.107    DEG_APCC_KENBOX_2
# 1       0.111    DEG_APCC_KENBOX_2
# 2       0.037    DEG_APCC_KENBOX_2
# 3       0.107    DEG_APCC_KENBOX_2
# 4       0.074    DEG_APCC_KENBOX_2
# ...       ...                  ...
# 3446    0.033  TRG_AP2beta_CARGO_1
# 3447    0.097  TRG_AP2beta_CARGO_1
# 3448    0.034  TRG_AP2beta_CARGO_1
# 3449    0.129  TRG_AP2beta_CARGO_1
# 3450    0.000  TRG_AP2beta_CARGO_1
#
# [3451 rows x 28 columns]

# %%
# check how predictions did not go through as some long predictions are tricky
run51[run51['model_id'] == 'Prediction failed'].shape
# Out:
# (16, 28)

# %%
# I made the mistake of duplicating some extensions as full length because some proteins after extension becomes
# full length, these should be de-duplicated
# I also only work with the best model as selected by the least RMSD_all_atom_peptide per predicton,
# the de-duplication will also filter for best model per prediction
run51_final_df = run51.sort_values(['RMSD_all_atom_peptide'],ascending=True).drop_duplicates(subset=['dmi_name','chainA_length',
                                                                           'chainB_length'],keep='first').copy()
run51_final_df.reset_index(drop=True,inplace=True)
print(run51_final_df.shape)
# Out:
# (703, 28)

# %%
# create motif extension step index 
# chainB is always the motif chain 
temp = run51_final_df.drop_duplicates(subset=['dmi_name','chainB_length']).copy()
motif_ext_index_df = temp.sort_values(['dmi_name','chainB_length'])[['dmi_name','chainB_length']].copy()
motif_ext_index_df['motif_ext_index'] = [i for v in motif_ext_index_df.groupby('dmi_name').size().values for i in range(0,v)]
motif_ext_index_df.reset_index(drop=True,inplace=True)
motif_ext_index_df
# Out:
#                 dmi_name  chainB_length  motif_ext_index
# 0      DEG_APCC_KENBOX_2              5                0
# 1      DEG_APCC_KENBOX_2             15                1
# 2      DEG_APCC_KENBOX_2             25                2
# 3      DEG_APCC_KENBOX_2             45                3
# 4      DEG_APCC_KENBOX_2             57                4
# ..                   ...            ...              ...
# 229  TRG_AP2beta_CARGO_1             55                2
# 230  TRG_AP2beta_CARGO_1             97                3
# 231  TRG_AP2beta_CARGO_1            119                4
# 232  TRG_AP2beta_CARGO_1            271                5
# 233  TRG_AP2beta_CARGO_1            308                6
#
# [234 rows x 3 columns]

# %% [markdown]
# motif_ext_index 6 as the full length

# %%
# create domain extension step index 
# chainA is always the domain chain 
temp = run51_final_df.drop_duplicates(subset=['dmi_name','chainA_length']).copy()
domain_ext_index_df = temp.sort_values(['dmi_name','chainA_length'])[['dmi_name','chainA_length']].copy()
domain_ext_index_df['domain_ext_index'] = [i for v in domain_ext_index_df.groupby('dmi_name').size().values for i in range(0,v)]
domain_ext_index_df.reset_index(drop=True,inplace=True)
domain_ext_index_df
# Out:
#                 dmi_name  chainA_length  domain_ext_index
# 0      DEG_APCC_KENBOX_2            307                 0
# 1      DEG_APCC_KENBOX_2            499                 1
# 2      DEG_Kelch_Keap1_1            280                 0
# 3      DEG_Kelch_Keap1_1            330                 1
# 4      DEG_Kelch_Keap1_1            450                 2
# ..                   ...            ...               ...
# 107             LIG_WW_1            438                 1
# 108  TRG_AP2beta_CARGO_1            232                 0
# 109  TRG_AP2beta_CARGO_1            396                 1
# 110  TRG_AP2beta_CARGO_1            934                 2
# 111  TRG_AP2beta_CARGO_1            937                 3
#
# [112 rows x 3 columns]

# %% [markdown]
# domain_ext_index 3 as the full length

# %%
run51_final_df = pd.merge(run51_final_df,domain_ext_index_df,how='outer',on=['dmi_name','chainA_length'])
run51_final_df = pd.merge(run51_final_df,motif_ext_index_df,how='outer',on=['dmi_name','chainB_length'])
run51_final_df
# Out:
#             project_name                          prediction_name run_id  \
# 0    AlphaFold_benchmark  run51_DOC_USP7_MATH_1_M392_M406_D1_D204  run51
# 1    AlphaFold_benchmark     run51_DOC_USP7_MATH_1_M392_M406_Dmin  run51
# 2    AlphaFold_benchmark  run51_DOC_USP7_MATH_1_M392_M406_D1_D528  run51
# 3    AlphaFold_benchmark      run51_DOC_USP7_MATH_1_M392_M406_DFL  run51
# 4    AlphaFold_benchmark  run51_DOC_USP7_MATH_1_M367_M431_D1_D204  run51
# ..                   ...                                      ...    ...
# 698  AlphaFold_benchmark           run51_LIG_CNOT1_NIM_1_MFL_Dmin  run51
# 699  AlphaFold_benchmark    run51_LIG_CNOT1_NIM_1_MFL_D1544_D2376  run51
# 700  AlphaFold_benchmark   run51_LIG_CNOT1_NIM_1_Mmin_D1377_D2376  run51
# 701  AlphaFold_benchmark   run51_LIG_CNOT1_NIM_1_Mmin_D1544_D2376  run51
# 702  AlphaFold_benchmark           run51_LIG_CNOT1_NIM_1_Mmin_DFL  run51
#
#      chainA_length  chainB_length           model_id  model_confidence  \
# 0              204             15           ranked_3          0.767290
# 1              138             15           ranked_1          0.842477
# 2              528             15           ranked_2          0.806106
# 3             1102             15           ranked_1          0.804861
# 4              204             65           ranked_1          0.639066
# ..             ...            ...                ...               ...
# 698            432            292           ranked_4          0.269018
# 699            833            292           ranked_3          0.259305
# 700           1000             10           ranked_0          0.562944
# 701            833             10           ranked_2          0.575764
# 702           2376             10  Prediction failed               NaN
#
#      chainA_intf_avg_plddt  chainB_intf_avg_plddt  intf_avg_plddt  ...  \
# 0                92.155000              72.967143       83.760313  ...
# 1                92.217895              76.384168       86.088710  ...
# 2                89.922353              67.459167       80.627241  ...
# 3                85.344286              62.245833       76.944849  ...
# 4                93.810000              79.608462       88.820270  ...
# ..                     ...                    ...             ...  ...
# 698              65.787500              28.328286       49.191646  ...
# 699              83.642308              25.267391       56.241837  ...
# 700              75.967692              29.968571       59.868000  ...
# 701              77.844668              32.111250       61.937392  ...
# 702                    NaN                    NaN             NaN  ...
#
#      RMSD_backbone_peptide RMSD_all_atom_peptide  known_motif_plddt  DockQ  \
# 0                 0.320134              0.430814          93.810001  0.969
# 1                 0.363519              0.478511          93.482001  0.966
# 2                 0.394953              0.510463          86.636000  0.966
# 3                 0.394756              0.564259          80.498000  0.961
# 4                 0.409387              0.465894          96.214001  0.969
# ..                     ...                   ...                ...    ...
# 698              18.786930             19.329712          26.486000  0.066
# 699              20.034286             19.930250          25.110000  0.061
# 700              14.524009             14.437459          29.346000  0.100
# 701              14.926224             14.601132          31.607000  0.096
# 702                    NaN                   NaN                NaN    NaN
#
#       iRMS    LRMS  Fnonnat         dmi_name  domain_ext_index  \
# 0    0.314   0.308    0.208  DOC_USP7_MATH_1                 1
# 1    0.350   0.323    0.208  DOC_USP7_MATH_1                 0
# 2    0.348   0.308    0.174  DOC_USP7_MATH_1                 2
# 3    0.395   0.371    0.208  DOC_USP7_MATH_1                 3
# 4    0.313   0.367    0.174  DOC_USP7_MATH_1                 1
# ..     ...     ...      ...              ...               ...
# 698  8.789  18.799    1.000  LIG_CNOT1_NIM_1                 0
# 699  8.519  20.063    1.000  LIG_CNOT1_NIM_1                 1
# 700  6.871  14.546    1.000  LIG_CNOT1_NIM_1                 2
# 701  7.001  14.947    1.000  LIG_CNOT1_NIM_1                 1
# 702    NaN     NaN      NaN  LIG_CNOT1_NIM_1                 3
#
#      motif_ext_index
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  4
# ..               ...
# 698                6
# 699                6
# 700                0
# 701                0
# 702                0
#
# [703 rows x 30 columns]

# %% [markdown]
# ### We later realized that some full length extensions (6th for motif extension and 3rd for domain extension) is marginal compared to the previous extension step. I have to manually check these cases and have them excluded from the analysis since the extensions are marginal and do not really count as meaningful extensions.

# %%
motif_ext_index_df.groupby('dmi_name').agg({'chainB_length':lambda x: ','.join(map(str,x)),
                                            'motif_ext_index':lambda x: ','.join(map(str,x))})
# Out:
#                                    chainB_length motif_ext_index
# dmi_name
# DEG_APCC_KENBOX_2         5,15,25,45,57,189,1050   0,1,2,3,4,5,6
# DEG_Kelch_Keap1_1          6,18,30,54,78,568,605   0,1,2,3,4,5,6
# DEG_MDM2_SWIB_1            8,24,40,58,74,298,393   0,1,2,3,4,5,6
# DEG_SIAH_1                9,27,45,81,117,166,228   0,1,2,3,4,5,6
# DOC_ANK_TNKS_1            8,24,40,72,104,322,350   0,1,2,3,4,5,6
# DOC_MAPK_JIP1_4            7,21,35,63,91,427,455   0,1,2,3,4,5,6
# DOC_SPAK_OSR1_1           5,15,25,45,65,801,1243   0,1,2,3,4,5,6
# DOC_USP7_MATH_1            5,15,25,45,65,202,491   0,1,2,3,4,5,6
# DOC_USP7_UBL2_3           5,15,25,37,42,682,1616   0,1,2,3,4,5,6
# LIG_BIR_III_2              5,15,25,45,65,266,416   0,1,2,3,4,5,6
# LIG_CAP-Gly_1                        5,7,33,1438         0,1,2,3
# LIG_CAP-Gly_2              7,14,21,35,49,462,581   0,1,2,3,4,5,6
# LIG_CNOT1_NIM_1          10,30,50,89,109,276,292   0,1,2,3,4,5,6
# LIG_EF_ALG2_ABM_1         9,27,45,81,117,466,868   0,1,2,3,4,5,6
# LIG_GYF                   9,27,45,81,111,227,351   0,1,2,3,4,5,6
# LIG_HOMEOBOX               4,12,20,36,52,270,301   0,1,2,3,4,5,6
# LIG_LIR_Gen_1            11,33,55,99,143,598,966   0,1,2,3,4,5,6
# LIG_LRP6_Inhibitor_1       7,21,35,63,85,149,266   0,1,2,3,4,5,6
# LIG_NBox_RRM_1           11,33,55,85,102,175,644   0,1,2,3,4,5,6
# LIG_NRBOX                 7,21,35,63,91,374,1464   0,1,2,3,4,5,6
# LIG_OCRL_FandH_1         13,39,53,79,105,238,249   0,1,2,3,4,5,6
# LIG_PAM2_1                    13,32,45,71,97,127     0,1,2,3,4,5
# LIG_PAM2_2             14,42,70,126,182,275,1690   0,1,2,3,4,5,6
# LIG_PCNA_PIPBox_1         10,30,41,61,81,154,164   0,1,2,3,4,5,6
# LIG_PCNA_TLS_4             8,17,25,41,57,470,870   0,1,2,3,4,5,6
# LIG_PDZ_Class_1           6,12,18,30,42,749,1601   0,1,2,3,4,5,6
# LIG_Pex14_3                6,18,30,54,78,412,639   0,1,2,3,4,5,6
# LIG_REV1ctd_RIR_1        12,36,60,99,123,470,870   0,1,2,3,4,5,6
# LIG_RPA_C_Vert          16,48,80,136,144,309,313   0,1,2,3,4,5,6
# LIG_TRFH_1                 5,15,25,45,65,442,451   0,1,2,3,4,5,6
# LIG_ULM_U2AF65_1           9,27,41,59,77,140,639   0,1,2,3,4,5,6
# LIG_Vh1_VBS_1         19,57,95,171,247,1788,2541   0,1,2,3,4,5,6
# LIG_WW_1                   4,11,15,23,31,299,895   0,1,2,3,4,5,6
# TRG_AP2beta_CARGO_1      11,33,55,97,119,271,308   0,1,2,3,4,5,6

# %% [markdown]
# Some full length motif extensions (step 6), is marginally different from step 5 that includes the neighboring domain. Katja said that those motif extension step 6 with less than 20 residues extended on either N or C terminus should be excluded from step 6. They are as follow:
#
# - LIG_CNOT1_NIM_1
# - LIG_OCRL_FandH_1
# - LIG_PCNA_PIPBox_1
# - LIG_RPA_C_Vert
# - LIG_TRFH_1

# %%
# prepare the indices of 6th motif extension step that will be excluded from analysis later
dmi_6th_motif_ext_marginal = ['LIG_CNOT1_NIM_1','LIG_OCRL_FandH_1','LIG_PCNA_PIPBox_1','LIG_RPA_C_Vert',
                             'LIG_TRFH_1']
dmi_6th_motif_ext_marginal_ind = run51_final_df[(run51_final_df['dmi_name'].isin(dmi_6th_motif_ext_marginal)) & (run51_final_df['motif_ext_index'] == 6)].index
len(dmi_6th_motif_ext_marginal_ind)
# Out:
# 14

# %%
domain_ext_index_df.groupby('dmi_name').agg({'chainA_length':lambda x: ','.join(map(str,x)),
                                            'domain_ext_index':lambda x: ','.join(map(str,x))})
# Out:
#                           chainA_length domain_ext_index
# dmi_name
# DEG_APCC_KENBOX_2               307,499              0,1
# DEG_Kelch_Keap1_1       280,330,450,624          0,1,2,3
# DEG_MDM2_SWIB_1          75,290,337,491          0,1,2,3
# DEG_SIAH_1                      188,282              0,1
# DOC_ANK_TNKS_1         155,199,352,1166          0,1,2,3
# DOC_MAPK_JIP1_4                 351,464              0,1
# DOC_SPAK_OSR1_1          57,227,521,527          0,1,2,3
# DOC_USP7_MATH_1        138,204,528,1102          0,1,2,3
# DOC_USP7_UBL2_3        245,338,893,1102          0,1,2,3
# LIG_BIR_III_2            66,198,342,497          0,1,2,3
# LIG_CAP-Gly_1           41,517,815,1278          0,1,2,3
# LIG_CAP-Gly_2           42,204,288,1438          0,1,2,3
# LIG_CNOT1_NIM_1       432,833,1000,2376          0,1,2,3
# LIG_EF_ALG2_ABM_1               163,191              0,1
# LIG_GYF                          57,341              0,1
# LIG_HOMEOBOX             68,189,401,430          0,1,2,3
# LIG_LIR_Gen_1                   110,117              0,1
# LIG_LRP6_Inhibitor_1   300,362,422,1613          0,1,2,3
# LIG_NBox_RRM_1                  191,559              0,1
# LIG_NRBOX               207,281,422,595          0,1,2,3
# LIG_OCRL_FandH_1        334,368,667,901          0,1,2,3
# LIG_PAM2_1               68,264,351,636          0,1,2,3
# LIG_PAM2_2               72,264,351,636          0,1,2,3
# LIG_PCNA_PIPBox_1               250,261              0,1
# LIG_PCNA_TLS_4                  250,261              0,1
# LIG_PDZ_Class_1         91,308,510,2485          0,1,2,3
# LIG_Pex14_3                      64,377              0,1
# LIG_REV1ctd_RIR_1       94,200,250,1251          0,1,2,3
# LIG_RPA_C_Vert                   88,270              0,1
# LIG_TRFH_1              202,370,437,439          0,1,2,3
# LIG_ULM_U2AF65_1         99,136,225,475          0,1,2,3
# LIG_Vh1_VBS_1          253,471,925,1134          0,1,2,3
# LIG_WW_1                        256,438              0,1
# TRG_AP2beta_CARGO_1     232,396,934,937          0,1,2,3

# %% [markdown]
# After manual checking, the following DMI's domain extension step 3 will be excluded because their full length extensions differ marginally to that of domain extension step 2 (less than 20 residues on N or C terminal of the 2nd domain extension):
# - DOC_SPAK_OSR1_1, domain ext 3
# - LIG_TRFH_1, domain ext 3
# - TRG_AP2beta_CARGO_1, domain ext 3
#
# LIG_HOMEOBOX has 29 residue extension on the N terminus as the third domain extension step and that makes it okay to be included in the analysis.

# %%
# prepare the indices of 3rd domain extension step that will be excluded from analysis later
dmi_3rd_domain_ext_marginal = ['DOC_SPAK_OSR1_1','LIG_TRFH_1','TRG_AP2beta_CARGO_1']
dmi_3rd_domain_ext_marginal_ind = run51_final_df[(run51_final_df['dmi_name'].isin(dmi_3rd_domain_ext_marginal)) & (run51_final_df['domain_ext_index'] == 3)].index
len(dmi_3rd_domain_ext_marginal_ind)
# Out:
# 19

# %%
# some indices are repeated in 3rd domain extension and 6th motif extension exclusion
# so make a union of the two lists first
len(set(dmi_3rd_domain_ext_marginal_ind).union(set(dmi_6th_motif_ext_marginal_ind)))
# Out:
# 32

# %%
# exclude the predictions involving 3rd domain extension that marginally extend the protein
run51_final_df.drop(index=set(dmi_3rd_domain_ext_marginal_ind).union(set(dmi_6th_motif_ext_marginal_ind)),inplace=True)
run51_final_df.reset_index(drop=True,inplace=True)
print(run51_final_df.shape)
run51_final_df
# Out:
# (671, 30)
#             project_name                            prediction_name run_id  \
# 0    AlphaFold_benchmark    run51_DOC_USP7_MATH_1_M392_M406_D1_D204  run51
# 1    AlphaFold_benchmark       run51_DOC_USP7_MATH_1_M392_M406_Dmin  run51
# 2    AlphaFold_benchmark    run51_DOC_USP7_MATH_1_M392_M406_D1_D528  run51
# 3    AlphaFold_benchmark        run51_DOC_USP7_MATH_1_M392_M406_DFL  run51
# 4    AlphaFold_benchmark    run51_DOC_USP7_MATH_1_M367_M431_D1_D204  run51
# ..                   ...                                        ...    ...
# 666  AlphaFold_benchmark  run51_LIG_CNOT1_NIM_1_M30_M59_D1377_D2376  run51
# 667  AlphaFold_benchmark  run51_LIG_CNOT1_NIM_1_M30_M59_D1544_D2376  run51
# 668  AlphaFold_benchmark     run51_LIG_CNOT1_NIM_1_Mmin_D1377_D2376  run51
# 669  AlphaFold_benchmark     run51_LIG_CNOT1_NIM_1_Mmin_D1544_D2376  run51
# 670  AlphaFold_benchmark             run51_LIG_CNOT1_NIM_1_Mmin_DFL  run51
#
#      chainA_length  chainB_length           model_id  model_confidence  \
# 0              204             15           ranked_3          0.767290
# 1              138             15           ranked_1          0.842477
# 2              528             15           ranked_2          0.806106
# 3             1102             15           ranked_1          0.804861
# 4              204             65           ranked_1          0.639066
# ..             ...            ...                ...               ...
# 666           1000             30           ranked_3          0.422069
# 667            833             30           ranked_4          0.420936
# 668           1000             10           ranked_0          0.562944
# 669            833             10           ranked_2          0.575764
# 670           2376             10  Prediction failed               NaN
#
#      chainA_intf_avg_plddt  chainB_intf_avg_plddt  intf_avg_plddt  ...  \
# 0                92.155000              72.967143       83.760313  ...
# 1                92.217895              76.384168       86.088710  ...
# 2                89.922353              67.459167       80.627241  ...
# 3                85.344286              62.245833       76.944849  ...
# 4                93.810000              79.608462       88.820270  ...
# ..                     ...                    ...             ...  ...
# 666              74.148999              30.209000       52.178999  ...
# 667              71.400000              33.881539       55.666452  ...
# 668              75.967692              29.968571       59.868000  ...
# 669              77.844668              32.111250       61.937392  ...
# 670                    NaN                    NaN             NaN  ...
#
#      RMSD_backbone_peptide RMSD_all_atom_peptide  known_motif_plddt  DockQ  \
# 0                 0.320134              0.430814          93.810001  0.969
# 1                 0.363519              0.478511          93.482001  0.966
# 2                 0.394953              0.510463          86.636000  0.966
# 3                 0.394756              0.564259          80.498000  0.961
# 4                 0.409387              0.465894          96.214001  0.969
# ..                     ...                   ...                ...    ...
# 666              16.797138             17.212463          30.992999  0.080
# 667              17.497913             17.666700          33.797000  0.075
# 668              14.524009             14.437459          29.346000  0.100
# 669              14.926224             14.601132          31.607000  0.096
# 670                    NaN                   NaN                NaN    NaN
#
#       iRMS    LRMS  Fnonnat         dmi_name  domain_ext_index  \
# 0    0.314   0.308    0.208  DOC_USP7_MATH_1                 1
# 1    0.350   0.323    0.208  DOC_USP7_MATH_1                 0
# 2    0.348   0.308    0.174  DOC_USP7_MATH_1                 2
# 3    0.395   0.371    0.208  DOC_USP7_MATH_1                 3
# 4    0.313   0.367    0.174  DOC_USP7_MATH_1                 1
# ..     ...     ...      ...              ...               ...
# 666  7.836  16.830    1.000  LIG_CNOT1_NIM_1                 2
# 667  7.808  17.546    1.000  LIG_CNOT1_NIM_1                 1
# 668  6.871  14.546    1.000  LIG_CNOT1_NIM_1                 2
# 669  7.001  14.947    1.000  LIG_CNOT1_NIM_1                 1
# 670    NaN     NaN      NaN  LIG_CNOT1_NIM_1                 3
#
#      motif_ext_index
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  4
# ..               ...
# 666                1
# 667                1
# 668                0
# 669                0
# 670                0
#
# [671 rows x 30 columns]

# %%
# make a copy of the final_df to work with
temp = run51_final_df[run51_final_df['model_id'] == 'Prediction failed'].copy()

# make a summary of the number of sample size in each extension step pairings
summary = temp.groupby(['domain_ext_index','motif_ext_index']).size().reset_index(name='size').pivot(index='motif_ext_index',
                                                                                              columns='domain_ext_index')

# fill NaNs with 0
summary.fillna(0,inplace=True)
summary = summary.astype('int')
summary
# Out:
#                  size
# domain_ext_index    0  1  2  3
# motif_ext_index
# 0                   0  0  1  2
# 1                   0  0  1  0
# 2                   0  0  1  0
# 3                   0  1  1  0
# 4                   0  0  1  0
# 5                   1  1  2  0
# 6                   0  2  1  1

# %%
run51_final_df[run51_final_df['model_id'] != 'Prediction failed']
# Out:
#             project_name                            prediction_name run_id  \
# 0    AlphaFold_benchmark    run51_DOC_USP7_MATH_1_M392_M406_D1_D204  run51
# 1    AlphaFold_benchmark       run51_DOC_USP7_MATH_1_M392_M406_Dmin  run51
# 2    AlphaFold_benchmark    run51_DOC_USP7_MATH_1_M392_M406_D1_D528  run51
# 3    AlphaFold_benchmark        run51_DOC_USP7_MATH_1_M392_M406_DFL  run51
# 4    AlphaFold_benchmark    run51_DOC_USP7_MATH_1_M367_M431_D1_D204  run51
# ..                   ...                                        ...    ...
# 665  AlphaFold_benchmark         run51_LIG_CNOT1_NIM_1_M30_M59_Dmin  run51
# 666  AlphaFold_benchmark  run51_LIG_CNOT1_NIM_1_M30_M59_D1377_D2376  run51
# 667  AlphaFold_benchmark  run51_LIG_CNOT1_NIM_1_M30_M59_D1544_D2376  run51
# 668  AlphaFold_benchmark     run51_LIG_CNOT1_NIM_1_Mmin_D1377_D2376  run51
# 669  AlphaFold_benchmark     run51_LIG_CNOT1_NIM_1_Mmin_D1544_D2376  run51
#
#      chainA_length  chainB_length  model_id  model_confidence  \
# 0              204             15  ranked_3          0.767290
# 1              138             15  ranked_1          0.842477
# 2              528             15  ranked_2          0.806106
# 3             1102             15  ranked_1          0.804861
# 4              204             65  ranked_1          0.639066
# ..             ...            ...       ...               ...
# 665            432             30  ranked_2          0.425966
# 666           1000             30  ranked_3          0.422069
# 667            833             30  ranked_4          0.420936
# 668           1000             10  ranked_0          0.562944
# 669            833             10  ranked_2          0.575764
#
#      chainA_intf_avg_plddt  chainB_intf_avg_plddt  intf_avg_plddt  ...  \
# 0                92.155000              72.967143       83.760313  ...
# 1                92.217895              76.384168       86.088710  ...
# 2                89.922353              67.459167       80.627241  ...
# 3                85.344286              62.245833       76.944849  ...
# 4                93.810000              79.608462       88.820270  ...
# ..                     ...                    ...             ...  ...
# 665              66.584737              31.838750       50.700857  ...
# 666              74.148999              30.209000       52.178999  ...
# 667              71.400000              33.881539       55.666452  ...
# 668              75.967692              29.968571       59.868000  ...
# 669              77.844668              32.111250       61.937392  ...
#
#      RMSD_backbone_peptide RMSD_all_atom_peptide  known_motif_plddt  DockQ  \
# 0                 0.320134              0.430814          93.810001  0.969
# 1                 0.363519              0.478511          93.482001  0.966
# 2                 0.394953              0.510463          86.636000  0.966
# 3                 0.394756              0.564259          80.498000  0.961
# 4                 0.409387              0.465894          96.214001  0.969
# ..                     ...                   ...                ...    ...
# 665              16.768314             17.190536          32.261000  0.080
# 666              16.797138             17.212463          30.992999  0.080
# 667              17.497913             17.666700          33.797000  0.075
# 668              14.524009             14.437459          29.346000  0.100
# 669              14.926224             14.601132          31.607000  0.096
#
#       iRMS    LRMS  Fnonnat         dmi_name  domain_ext_index  \
# 0    0.314   0.308    0.208  DOC_USP7_MATH_1                 1
# 1    0.350   0.323    0.208  DOC_USP7_MATH_1                 0
# 2    0.348   0.308    0.174  DOC_USP7_MATH_1                 2
# 3    0.395   0.371    0.208  DOC_USP7_MATH_1                 3
# 4    0.313   0.367    0.174  DOC_USP7_MATH_1                 1
# ..     ...     ...      ...              ...               ...
# 665  7.866  16.804    1.000  LIG_CNOT1_NIM_1                 0
# 666  7.836  16.830    1.000  LIG_CNOT1_NIM_1                 2
# 667  7.808  17.546    1.000  LIG_CNOT1_NIM_1                 1
# 668  6.871  14.546    1.000  LIG_CNOT1_NIM_1                 2
# 669  7.001  14.947    1.000  LIG_CNOT1_NIM_1                 1
#
#      motif_ext_index
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  4
# ..               ...
# 665                1
# 666                1
# 667                1
# 668                0
# 669                0
#
# [655 rows x 30 columns]

# %%
# I want to use the index of final_df to find those that are not predicted in run51_final_df so as to exclude them
temp = run51_final_df[run51_final_df['model_id'] != 'Prediction failed'].copy()
temp = list(zip(temp['dmi_name'],temp['chainA_length'],temp['chainB_length']))
temp2 = list(zip(final_df['dmi_name'],final_df['chainA_length'],final_df['chainB_length']))
exclude_ind = []

for i, ele in enumerate(temp2):
    if ele not in temp:
        exclude_ind.append(i)

print(final_df.shape)
final_df.drop(index=exclude_ind,inplace=True)
print(final_df.shape)
# Out:
# (632, 30)
# (616, 30)

# %% [markdown]
# Check again the number of predictions that we still have in every motif-domain extension pair

# %%
# make a copy of the final_df to work with
temp = final_df.copy()

# make a summary of the number of sample size in each extension step pairings
summary = temp.groupby(['domain_ext_index','motif_ext_index']).size().reset_index(name='size').pivot(index='motif_ext_index',
                                                                                              columns='domain_ext_index')

# fill 0x0 with the number of DMIs selected for extension
summary.iloc[0,0] = len(temp.dmi_name.unique())
summary = summary.astype('int')
summary
# Out:
#                  size
# domain_ext_index    0   1   2   3
# motif_ext_index
# 0                  31  31  21  17
# 1                  31  31  21  17
# 2                  31  31  21  17
# 3                  31  30  20  16
# 4                  30  30  20  15
# 5                  29  29  19  15
# 6                  23  20  12   8

# %% [markdown]
# ### Retrieve minimal fragment information for analysis on how the extensions affect their prediction accuracy compared to minimal fragment predictions

# %%
def parse_prediction_name(prediction_name):
    """Parse out different components in the standard name for a minimal DMI prediction (e.g. run37_DEG_APCC_KENBOX_2_4GGD)

    Args:
        prediction_name (str): Name of the folder containing the AlphaFold predicted structure

    Returns:
        run_id (str): Run ID
        dmi_name (str): Name of DMI type
        pdb_id (str): PDB ID
    """
    splits = prediction_name.split('_')
    run_id = splits[0]
    dmi_name = '_'.join(splits[1:-1])
    pdb_id = splits[-1]
    return [run_id, dmi_name, pdb_id]

min_df = pd.read_csv('/Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run37/run37_template_indep_dep_info.tsv',
                sep='\t',index_col=0)

min_df[['run_id','dmi_name','pdb_id']] = min_df.apply(lambda x: parse_prediction_name(x['prediction_name']),
                                                                        axis=1,result_type='expand')
min_df = min_df[['dmi_name','RMSD_all_atom_peptide','DockQ','model_confidence','intf_avg_plddt',
                 'chainB_intf_avg_plddt','pDockQ']].copy()
min_df = min_df.sort_values(['RMSD_all_atom_peptide'],ascending=True).drop_duplicates(subset=['dmi_name'],keep='first').copy()
print(min_df.shape)

# filter for only DMI types that are used for extensions
min_df = min_df[min_df['dmi_name'].isin(final_df.dmi_name.unique())].copy()
print(min_df.shape)
# Out:
# (136, 7)
# (31, 7)

# %%
condlist = [min_df['RMSD_all_atom_peptide'] <= 2,
           (min_df['RMSD_all_atom_peptide'] > 2) & (min_df['RMSD_all_atom_peptide'] <= 5),
            (min_df['RMSD_all_atom_peptide'] > 5) & (min_df['RMSD_all_atom_peptide'] <= 15),
            min_df['RMSD_all_atom_peptide'] > 15]
choicelist = ['correct_sidechain','correct_backbone','correct_pocket','wrong_pocket']
min_df['RMSD_all_atom_peptide_classification'] = np.select(condlist,choicelist)

min_df.groupby('RMSD_all_atom_peptide_classification').size()
# Out:
# RMSD_all_atom_peptide_classification
# correct_backbone      8
# correct_pocket       11
# correct_sidechain    12
# dtype: int64

# %%
# join RMSD_domain and RMSD_peptide with agg_min_df so that I can calculate the difference of RMSD after extension
merged_df = pd.merge(final_df, min_df, how='inner',on='dmi_name',suffixes=['','_min_frag'])

# calculate difference in peptide RMSD then the fold change
merged_df['RMSD_all_atom_peptide_fold_change'] = np.log2(merged_df['RMSD_all_atom_peptide_min_frag'] / merged_df['RMSD_all_atom_peptide'])

# calculate the change in DockQ after extension
merged_df['DockQ_ext-DockQ_min'] = merged_df['DockQ'] - merged_df['DockQ_min_frag']
merged_df
# Out:
#             project_name                            prediction_name run_id  \
# 0    AlphaFold_benchmark              run39_DEG_SIAH_1_M41_M85_Dmin  run39
# 1    AlphaFold_benchmark           run39_DEG_SIAH_1_M41_M85_D1_D282  run39
# 2    AlphaFold_benchmark              run39_DEG_SIAH_1_M5_M121_Dmin  run39
# 3    AlphaFold_benchmark           run39_DEG_SIAH_1_M5_M121_D1_D282  run39
# 4    AlphaFold_benchmark             run39_DEG_SIAH_1_M23_M103_Dmin  run39
# ..                   ...                                        ...    ...
# 611  AlphaFold_benchmark   run40_LIG_CNOT1_NIM_1_M1_M89_D1377_D2376  run40
# 612  AlphaFold_benchmark          run39_LIG_CNOT1_NIM_1_M1_M89_Dmin  run39
# 613  AlphaFold_benchmark  run40_LIG_CNOT1_NIM_1_M1_M276_D1544_D2376  run40
# 614  AlphaFold_benchmark  run40_LIG_CNOT1_NIM_1_M1_M276_D1377_D2376  run40
# 615  AlphaFold_benchmark         run39_LIG_CNOT1_NIM_1_M1_M276_Dmin  run39
#
#      chainA_length  chainB_length  model_id  model_confidence  \
# 0              188             45  ranked_2          0.749542
# 1              282             45  ranked_3          0.648164
# 2              188            117  ranked_2          0.638711
# 3              282            117  ranked_2          0.578105
# 4              188             81  ranked_2          0.651657
# ..             ...            ...       ...               ...
# 611           1000             89  ranked_2          0.250435
# 612            432             89  ranked_4          0.277345
# 613            833            276  ranked_3          0.249178
# 614           1000            276  ranked_0          0.298145
# 615            432            276  ranked_2          0.249707
#
#      chainA_intf_avg_plddt  chainB_intf_avg_plddt  intf_avg_plddt  ...  \
# 0                89.468124              61.922609       77.949091  ...
# 1                89.451112              56.308334       76.194001  ...
# 2                86.530357              67.089444       78.923043  ...
# 3                89.676072              70.348235       82.374444  ...
# 4                88.818000              63.364287       79.680769  ...
# ..                     ...                    ...             ...  ...
# 611              60.305715              29.795000       46.223846  ...
# 612              71.933333              32.926471       51.210938  ...
# 613              71.964001              24.209285       52.300294  ...
# 614              85.526667              73.312001       79.097895  ...
# 615              71.190345              30.781923       52.088182  ...
#
#      motif_ext_index  RMSD_all_atom_peptide_min_frag  DockQ_min_frag  \
# 0                  2                        0.787199           0.959
# 1                  2                        0.787199           0.959
# 2                  4                        0.787199           0.959
# 3                  4                        0.787199           0.959
# 4                  3                        0.787199           0.959
# ..               ...                             ...             ...
# 611                3                       14.618848           0.118
# 612                3                       14.618848           0.118
# 613                5                       14.618848           0.118
# 614                5                       14.618848           0.118
# 615                5                       14.618848           0.118
#
#      model_confidence_min_frag  intf_avg_plddt_min_frag  \
# 0                     0.920907                95.023548
# 1                     0.920907                95.023548
# 2                     0.920907                95.023548
# 3                     0.920907                95.023548
# 4                     0.920907                95.023548
# ..                         ...                      ...
# 611                   0.410193                55.482857
# 612                   0.410193                55.482857
# 613                   0.410193                55.482857
# 614                   0.410193                55.482857
# 615                   0.410193                55.482857
#
#      chainB_intf_avg_plddt_min_frag  pDockQ_min_frag  \
# 0                         92.233334         0.463805
# 1                         92.233334         0.463805
# 2                         92.233334         0.463805
# 3                         92.233334         0.463805
# 4                         92.233334         0.463805
# ..                              ...              ...
# 611                       28.097143         0.023889
# 612                       28.097143         0.023889
# 613                       28.097143         0.023889
# 614                       28.097143         0.023889
# 615                       28.097143         0.023889
#
#      RMSD_all_atom_peptide_classification  RMSD_all_atom_peptide_fold_change  \
# 0                       correct_sidechain                           0.625203
# 1                       correct_sidechain                           0.540500
# 2                       correct_sidechain                           0.532265
# 3                       correct_sidechain                           0.483788
# 4                       correct_sidechain                           0.507659
# ..                                    ...                                ...
# 611                        correct_pocket                          -0.184018
# 612                        correct_pocket                          -0.424246
# 613                        correct_pocket                          -0.602793
# 614                        correct_pocket                          -1.019181
# 615                        correct_pocket                          -0.484248
#
#      DockQ_ext-DockQ_min
# 0                  0.007
# 1                  0.009
# 2                  0.005
# 3                  0.008
# 4                  0.004
# ..                   ...
# 611               -0.023
# 612               -0.053
# 613               -0.065
# 614               -0.085
# 615               -0.059
#
# [616 rows x 39 columns]

# %%
# classify the RMSD peptide before extension (minimal)
condlist = [merged_df['RMSD_all_atom_peptide_min_frag'] <= 2,
           (merged_df['RMSD_all_atom_peptide_min_frag'] > 2) & (merged_df['RMSD_all_atom_peptide_min_frag'] <= 5),
            (merged_df['RMSD_all_atom_peptide_min_frag'] > 5) & (merged_df['RMSD_all_atom_peptide_min_frag'] <= 15),
            merged_df['RMSD_all_atom_peptide_min_frag'] > 15]
choicelist = ['correct_sidechain','correct_backbone','correct_pocket','wrong_pocket']
merged_df['RMSD_all_atom_peptide_classification_min_frag'] = np.select(condlist,choicelist)

merged_df
# Out:
#             project_name                            prediction_name run_id  \
# 0    AlphaFold_benchmark              run39_DEG_SIAH_1_M41_M85_Dmin  run39
# 1    AlphaFold_benchmark           run39_DEG_SIAH_1_M41_M85_D1_D282  run39
# 2    AlphaFold_benchmark              run39_DEG_SIAH_1_M5_M121_Dmin  run39
# 3    AlphaFold_benchmark           run39_DEG_SIAH_1_M5_M121_D1_D282  run39
# 4    AlphaFold_benchmark             run39_DEG_SIAH_1_M23_M103_Dmin  run39
# ..                   ...                                        ...    ...
# 611  AlphaFold_benchmark   run40_LIG_CNOT1_NIM_1_M1_M89_D1377_D2376  run40
# 612  AlphaFold_benchmark          run39_LIG_CNOT1_NIM_1_M1_M89_Dmin  run39
# 613  AlphaFold_benchmark  run40_LIG_CNOT1_NIM_1_M1_M276_D1544_D2376  run40
# 614  AlphaFold_benchmark  run40_LIG_CNOT1_NIM_1_M1_M276_D1377_D2376  run40
# 615  AlphaFold_benchmark         run39_LIG_CNOT1_NIM_1_M1_M276_Dmin  run39
#
#      chainA_length  chainB_length  model_id  model_confidence  \
# 0              188             45  ranked_2          0.749542
# 1              282             45  ranked_3          0.648164
# 2              188            117  ranked_2          0.638711
# 3              282            117  ranked_2          0.578105
# 4              188             81  ranked_2          0.651657
# ..             ...            ...       ...               ...
# 611           1000             89  ranked_2          0.250435
# 612            432             89  ranked_4          0.277345
# 613            833            276  ranked_3          0.249178
# 614           1000            276  ranked_0          0.298145
# 615            432            276  ranked_2          0.249707
#
#      chainA_intf_avg_plddt  chainB_intf_avg_plddt  intf_avg_plddt  ...  \
# 0                89.468124              61.922609       77.949091  ...
# 1                89.451112              56.308334       76.194001  ...
# 2                86.530357              67.089444       78.923043  ...
# 3                89.676072              70.348235       82.374444  ...
# 4                88.818000              63.364287       79.680769  ...
# ..                     ...                    ...             ...  ...
# 611              60.305715              29.795000       46.223846  ...
# 612              71.933333              32.926471       51.210938  ...
# 613              71.964001              24.209285       52.300294  ...
# 614              85.526667              73.312001       79.097895  ...
# 615              71.190345              30.781923       52.088182  ...
#
#      RMSD_all_atom_peptide_min_frag  DockQ_min_frag  \
# 0                          0.787199           0.959
# 1                          0.787199           0.959
# 2                          0.787199           0.959
# 3                          0.787199           0.959
# 4                          0.787199           0.959
# ..                              ...             ...
# 611                       14.618848           0.118
# 612                       14.618848           0.118
# 613                       14.618848           0.118
# 614                       14.618848           0.118
# 615                       14.618848           0.118
#
#      model_confidence_min_frag  intf_avg_plddt_min_frag  \
# 0                     0.920907                95.023548
# 1                     0.920907                95.023548
# 2                     0.920907                95.023548
# 3                     0.920907                95.023548
# 4                     0.920907                95.023548
# ..                         ...                      ...
# 611                   0.410193                55.482857
# 612                   0.410193                55.482857
# 613                   0.410193                55.482857
# 614                   0.410193                55.482857
# 615                   0.410193                55.482857
#
#      chainB_intf_avg_plddt_min_frag  pDockQ_min_frag  \
# 0                         92.233334         0.463805
# 1                         92.233334         0.463805
# 2                         92.233334         0.463805
# 3                         92.233334         0.463805
# 4                         92.233334         0.463805
# ..                              ...              ...
# 611                       28.097143         0.023889
# 612                       28.097143         0.023889
# 613                       28.097143         0.023889
# 614                       28.097143         0.023889
# 615                       28.097143         0.023889
#
#      RMSD_all_atom_peptide_classification  RMSD_all_atom_peptide_fold_change  \
# 0                       correct_sidechain                           0.625203
# 1                       correct_sidechain                           0.540500
# 2                       correct_sidechain                           0.532265
# 3                       correct_sidechain                           0.483788
# 4                       correct_sidechain                           0.507659
# ..                                    ...                                ...
# 611                        correct_pocket                          -0.184018
# 612                        correct_pocket                          -0.424246
# 613                        correct_pocket                          -0.602793
# 614                        correct_pocket                          -1.019181
# 615                        correct_pocket                          -0.484248
#
#      DockQ_ext-DockQ_min  RMSD_all_atom_peptide_classification_min_frag
# 0                  0.007                              correct_sidechain
# 1                  0.009                              correct_sidechain
# 2                  0.005                              correct_sidechain
# 3                  0.008                              correct_sidechain
# 4                  0.004                              correct_sidechain
# ..                   ...                                            ...
# 611               -0.023                                 correct_pocket
# 612               -0.053                                 correct_pocket
# 613               -0.065                                 correct_pocket
# 614               -0.085                                 correct_pocket
# 615               -0.059                                 correct_pocket
#
# [616 rows x 40 columns]

# %% [markdown]
# ----
# ### Finished pre-processing and prediction checking, start analyzing benchmark metrics

# %%
save_path = '/Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/Plots/DMI_types_extensions/AF2_MMv2.2_v2.3_comparison/'
# pivot the table for heatmap plotting
temp = merged_df[['domain_ext_index','motif_ext_index','RMSD_all_atom_peptide_fold_change']].pivot_table(index='motif_ext_index',
                                                                                   columns='domain_ext_index',
                                                                                   values='RMSD_all_atom_peptide_fold_change',
                                                                                   aggfunc=np.mean).fillna(0).copy()

fig, ax = plt.subplots(figsize=(4,4))
sns.heatmap(temp,annot=False,center=0,cmap=sns.diverging_palette(250, 18, as_cmap=True),vmin=-2.5,vmax=0.5,
           cbar_kws={'label': 'log$_{\mathrm{2}}$(RMSD$_{\mathrm{min}}$/RMSD$_{\mathrm{ext}}$)'})
plt.ylabel('Motif extension step',fontsize=global_fontsize)
plt.xlabel('Domain extension step',fontsize=global_fontsize)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=global_fontsize)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=global_fontsize)
plt.title('AF-MM v2.2 (also predicted in AF-MM v2.3)',fontsize=global_fontsize)

plt.savefig(f'{save_path}domain_motif_ext_peptide_fold_change_heatmap.pdf',transparent=True,
           bbox_inches='tight')
plt.savefig(f'{save_path}domain_motif_ext_peptide_fold_change_heatmap.jpeg',transparent=True,dpi=300,
           bbox_inches='tight')
plt.show()

fig, ax = plt.subplots(figsize=(4,4))
sns.heatmap(temp,annot=True,center=0,cmap=sns.diverging_palette(250, 18, as_cmap=True),vmin=-2.5,vmax=0.5,
           cbar_kws={'label': 'log$_{\mathrm{2}}$(RMSD$_{\mathrm{min}}$/RMSD$_{\mathrm{ext}}$)'})
plt.ylabel('Motif extension step',fontsize=global_fontsize)
plt.xlabel('Domain extension step',fontsize=global_fontsize)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=global_fontsize)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=global_fontsize)
plt.title('AF-MM v2.2 (also predicted in AF-MM v2.3)',fontsize=global_fontsize)

plt.savefig(f'{save_path}domain_motif_ext_peptide_fold_change_heatmap_annot.pdf',transparent=True,
           bbox_inches='tight')
plt.savefig(f'{save_path}domain_motif_ext_peptide_fold_change_heatmap_annot.jpeg',transparent=True,dpi=300,
           bbox_inches='tight')
plt.show()

# %%
# pivot the table for heatmap plotting
temp = merged_df[['domain_ext_index','motif_ext_index','DockQ_ext-DockQ_min']].pivot_table(index='motif_ext_index',
                                                                                   columns='domain_ext_index',
                                                                                   values='DockQ_ext-DockQ_min',
                                                                                   aggfunc=np.mean).fillna(0).copy()

fig, ax = plt.subplots(figsize=(4,4))
sns.heatmap(temp,annot=False,center=0,cmap=sns.diverging_palette(250, 18, as_cmap=True),vmin=-0.36,vmax=0.06,
           cbar_kws={'label': "DockQ$_{\mathrm{ext}}$ - DockQ$_{\mathrm{min}}$"})
plt.ylabel('Motif extension step',fontsize=global_fontsize)
plt.xlabel('Domain extension step',fontsize=global_fontsize)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=global_fontsize)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=global_fontsize)
plt.title('AF-MM v2.2 (also predicted in AF-MM v2.3)',fontsize=global_fontsize)

plt.savefig(f'{save_path}DockQ_ext-DockQ_min_heatmap.pdf',transparent=True,
           bbox_inches='tight')
plt.savefig(f'{save_path}DockQ_ext-DockQ_min_heatmap.jpeg',transparent=True,dpi=300,
           bbox_inches='tight')
plt.show()

fig, ax = plt.subplots(figsize=(4,4))
sns.heatmap(temp,annot=True,center=0,cmap=sns.diverging_palette(250, 18, as_cmap=True),vmin=-0.36,vmax=0.06,
           cbar_kws={'label': "DockQ$_{\mathrm{ext}}$ - DockQ$_{\mathrm{min}}$"})
plt.ylabel('Motif extension step',fontsize=global_fontsize)
plt.xlabel('Domain extension step',fontsize=global_fontsize)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=global_fontsize)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=global_fontsize)
plt.title('AF-MM v2.2 (also predicted in AF-MM v2.3)',fontsize=global_fontsize)

plt.savefig(f'{save_path}DockQ_ext-DockQ_min_heatmap_annot.pdf',transparent=True,
           bbox_inches='tight')
plt.savefig(f'{save_path}DockQ_ext-DockQ_min_heatmap_annot.jpeg',transparent=True,dpi=300,
           bbox_inches='tight')
plt.show()

# %%
# pivot the table for heatmap plotting
temp = merged_df[['domain_ext_index','motif_ext_index','model_confidence']].pivot_table(index='motif_ext_index',
                                                                                   columns='domain_ext_index',
                                                                                   values='model_confidence',
                                                                                   aggfunc=np.mean).copy()

# calculate the value to fill for 0 x 0 extension
temp.fillna(np.mean(min_df.model_confidence),inplace=True)

fig, ax = plt.subplots(figsize=(4,4))
sns.heatmap(temp,annot=False,cmap=sns.color_palette("Reds", as_cmap=True),vmin=0.3,vmax=0.9,
           cbar_kws={'label': 'Average model confidence'})
plt.ylabel('Motif extension step',fontsize=global_fontsize)
plt.xlabel('Domain extension step',fontsize=global_fontsize)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=global_fontsize)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=global_fontsize)
plt.title('AF-MM v2.2 (also predicted in AF-MM v2.3)',fontsize=global_fontsize)

plt.savefig(f'{save_path}domain_motif_ext_model_confidence_heatmap.pdf',transparent=True,
           bbox_inches='tight')
plt.savefig(f'{save_path}domain_motif_ext_model_confidence_heatmap.jpeg',transparent=True,dpi=300,
           bbox_inches='tight')
plt.show()

fig, ax = plt.subplots(figsize=(4,4))
sns.heatmap(temp,annot=True,cmap=sns.color_palette("Reds", as_cmap=True),vmin=0.3,vmax=0.9,
           cbar_kws={'label': 'Average model confidence'})
plt.ylabel('Motif extension step',fontsize=global_fontsize)
plt.xlabel('Domain extension step',fontsize=global_fontsize)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=global_fontsize)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=global_fontsize)
plt.title('AF-MM v2.2 (also predicted in AF-MM v2.3)',fontsize=global_fontsize)

plt.savefig(f'{save_path}domain_motif_ext_model_confidence_heatmap_annot.pdf',transparent=True,
           bbox_inches='tight')
plt.savefig(f'{save_path}domain_motif_ext_model_confidence_heatmap_annot.jpeg',transparent=True,dpi=300,
           bbox_inches='tight')
plt.show()

# %%
# pivot the table for heatmap plotting
temp = merged_df[['domain_ext_index','motif_ext_index','chainB_intf_avg_plddt']].pivot_table(index='motif_ext_index',
                                                                                   columns='domain_ext_index',
                                                                                   values='chainB_intf_avg_plddt',
                                                                                   aggfunc=np.mean).copy()

# calculate the value to fill for 0 x 0 extension
temp.fillna(np.mean(min_df.intf_avg_plddt),inplace=True)

fig, ax = plt.subplots(figsize=(4,4))
sns.heatmap(temp,annot=False,cmap=sns.color_palette("Reds", as_cmap=True),vmin=50,vmax=90,
           cbar_kws={'ticks':[50,60,70,80,90],'label': 'Motif chain interface pLDDT'})
plt.ylabel('Motif extension step',fontsize=global_fontsize)
plt.xlabel('Domain extension step',fontsize=global_fontsize)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=global_fontsize)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=global_fontsize)
plt.title('AF-MM v2.2 (also predicted in AF-MM v2.3)',fontsize=global_fontsize)

plt.savefig(f'{save_path}domain_motif_ext_chainB_intf_avg_plddt_heatmap.pdf',transparent=True,
           bbox_inches='tight')
plt.savefig(f'{save_path}domain_motif_ext_chainB_intf_avg_plddt_heatmap.jpeg',transparent=True,dpi=300,
           bbox_inches='tight')
plt.show()

fig, ax = plt.subplots(figsize=(4,4))
sns.heatmap(temp,annot=True,cmap=sns.color_palette("Reds", as_cmap=True),vmin=50,vmax=90,
           cbar_kws={'ticks':[50,60,70,80,90],'label': 'Average motif chain interface pLDDT'})
plt.ylabel('Motif extension step',fontsize=global_fontsize)
plt.xlabel('Domain extension step',fontsize=global_fontsize)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=global_fontsize)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=global_fontsize)
plt.title('AF-MM v2.2 (also predicted in AF-MM v2.3)',fontsize=global_fontsize)

plt.savefig(f'{save_path}domain_motif_ext_chainB_intf_avg_plddt_heatmap_annot.pdf',transparent=True,
           bbox_inches='tight')
plt.savefig(f'{save_path}domain_motif_ext_chainB_intf_avg_plddt_heatmap_annot.jpeg',transparent=True,dpi=300,
           bbox_inches='tight')
plt.show()

# %%
# pivot the table for heatmap plotting
temp = merged_df[['domain_ext_index','motif_ext_index','pDockQ']].pivot_table(index='motif_ext_index',
                                                                                   columns='domain_ext_index',
                                                                                   values='pDockQ',
                                                                                   aggfunc=np.mean).copy()

# calculate the value to fill for 0 x 0 extension
temp.fillna(np.mean(min_df.pDockQ),inplace=True)

fig, ax = plt.subplots(figsize=(4,4))
sns.heatmap(temp,annot=False,cmap=sns.color_palette("Reds", as_cmap=True),vmin=0.0,vmax=0.3,
           cbar_kws={'label': 'Average pDockQ'})
plt.ylabel('Motif extension step',fontsize=global_fontsize)
plt.xlabel('Domain extension step',fontsize=global_fontsize)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=global_fontsize)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=global_fontsize)
plt.title('AF-MM v2.2',fontsize=global_fontsize)

plt.savefig(f'{save_path}domain_motif_ext_pDockQ_heatmap.pdf',transparent=True,
           bbox_inches='tight')
plt.savefig(f'{save_path}domain_motif_ext_pDockQ_heatmap.jpeg',transparent=True,dpi=300,
           bbox_inches='tight')
plt.show()

fig, ax = plt.subplots(figsize=(4,4))
sns.heatmap(temp,annot=True,cmap=sns.color_palette("Reds", as_cmap=True),vmin=0.0,vmax=0.3,
           cbar_kws={'label': 'Average pDockQ'})
plt.ylabel('Motif extension step',fontsize=global_fontsize)
plt.xlabel('Domain extension step',fontsize=global_fontsize)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=global_fontsize)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=global_fontsize)
plt.title('AF-MM v2.2 (also predicted in AF-MM v2.3)',fontsize=global_fontsize)

plt.savefig(f'{save_path}domain_motif_ext_pDockQ_heatmap_annot.pdf',transparent=True,
           bbox_inches='tight')
plt.savefig(f'{save_path}domain_motif_ext_pDockQ_heatmap_annot.jpeg',transparent=True,dpi=300,
           bbox_inches='tight')
plt.show()

# %% [markdown]
# ----
# Below are codes use to save files that are to be sent to Julia

# %%
Julia = ['DEG_APCC_KENBOX_2_M1_M189_D1_D499','DEG_APCC_KENBOX_2_MFL_DFL','DOC_MAPK_JIP1_4_M29_M455_Dmin','DOC_MAPK_JIP1_4_MFL_Dmin','LIG_Vh1_VBS_1_Mmin_DFL','LIG_Vh1_VBS_1_M532_M702_DFL','LIG_Vh1_VBS_1_M570_M664_Dmin','LIG_Vh1_VBS_1_M532_M702_Dmin']
Julia_ind = []
for i, r in merged_df.iterrows():
    short_name = r['prediction_name'].lstrip(f"{r['run_id']}_")
    if short_name in Julia:
        Julia_ind.append(i)
Julia_ind
# Out:
# [58, 62, 299, 311, 313, 316, 340, 342]

# %%
merged_df.loc[Julia_ind,:].to_csv('/Volumes/imb-luckgr/projects/dmi_predictor/Julia/AF-MMv2.2_extended_PRS_competition_inspection/calculated_metrics.tsv',
                                 sep='\t')

# %%
dst = '/Volumes/imb-luckgr/projects/dmi_predictor/Julia/AF-MMv2.2_extended_PRS_competition_inspection'
for i, r in merged_df.loc[Julia_ind,:].iterrows():
    prediction_name = r['prediction_name']
    run_id = r['run_id']
    model_id = r['model_id']
    os.makedirs(f'{dst}/{prediction_name}')
    shutil.copy(src=f'/Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/{run_id}/{prediction_name}/{model_id}_superimpose.pse',
                dst=f'{dst}/{prediction_name}')

# %%
merged_df[merged_df['motif_ext_index'].isin([0,1]) & merged_df['domain_ext_index'].isin([1])].sort_values('dmi_name')
# Out:
#             project_name                                prediction_name  \
# 60   AlphaFold_benchmark        run39_DEG_APCC_KENBOX_2_M20_M34_D1_D499
# 63   AlphaFold_benchmark           run39_DEG_APCC_KENBOX_2_Mmin_D1_D499
# 83   AlphaFold_benchmark      run39_DEG_Kelch_Keap1_1_M71_M88_D295_D624
# 90   AlphaFold_benchmark         run39_DEG_Kelch_Keap1_1_Mmin_D295_D624
# 157  AlphaFold_benchmark             run39_DEG_MDM2_SWIB_1_Mmin_D1_D290
# ..                   ...                                            ...
# 304  AlphaFold_benchmark          run39_LIG_Vh1_VBS_1_M589_M645_D1_D471
# 222  AlphaFold_benchmark                run39_LIG_WW_1_Mmin_D2925_D3362
# 218  AlphaFold_benchmark           run39_LIG_WW_1_M885_M895_D2925_D3362
# 297  AlphaFold_benchmark       run39_TRG_AP2beta_CARGO_1_Mmin_D542_D937
# 280  AlphaFold_benchmark  run39_TRG_AP2beta_CARGO_1_M245_M277_D542_D937
#
#     run_id  chainA_length  chainB_length  model_id  model_confidence  \
# 60   run39            499             15  ranked_2          0.814075
# 63   run39            499              5  ranked_1          0.881369
# 83   run39            330             18  ranked_3          0.864065
# 90   run39            330              6  ranked_0          0.934373
# 157  run39            290              8  ranked_1          0.838298
# ..     ...            ...            ...       ...               ...
# 304  run39            471             57  ranked_2          0.593029
# 222  run39            438              4  ranked_2          0.856499
# 218  run39            438             11  ranked_1          0.761922
# 297  run39            396             11  ranked_0          0.883154
# 280  run39            396             33  ranked_3          0.672867
#
#      chainA_intf_avg_plddt  chainB_intf_avg_plddt  intf_avg_plddt  ...  \
# 60               95.864444              81.386666       91.038518  ...
# 63               96.938749              85.943999       94.320952  ...
# 83               98.230000              89.088000       95.182667  ...
# 90               98.708333              92.824998       97.237499  ...
# 157              93.932353              93.865000       93.914783  ...
# ..                     ...                    ...             ...  ...
# 304              87.977142              73.167097       82.238249  ...
# 222              95.938888              81.627499       91.535383  ...
# 218              92.580000              69.948572       85.036191  ...
# 297              97.590667              91.610001       95.347917  ...
# 280              96.874737              85.070714       91.866970  ...
#
#      motif_ext_index  RMSD_all_atom_peptide_min_frag  DockQ_min_frag  \
# 60                 1                        1.553759           0.881
# 63                 0                        1.553759           0.881
# 83                 1                        0.914587           0.968
# 90                 0                        0.914587           0.968
# 157                0                        1.099829           0.928
# ..               ...                             ...             ...
# 304                1                        1.482141           0.846
# 222                0                        1.052220           0.961
# 218                1                        1.052220           0.961
# 297                0                        1.841941           0.909
# 280                1                        1.841941           0.909
#
#      model_confidence_min_frag  intf_avg_plddt_min_frag  \
# 60                    0.871984                89.736111
# 63                    0.871984                89.736111
# 83                    0.938596                96.228333
# 90                    0.938596                96.228333
# 157                   0.883411                97.289091
# ..                         ...                      ...
# 304                   0.943860                96.589591
# 222                   0.932109                95.162143
# 218                   0.932109                95.162143
# 297                   0.881437                91.153914
# 280                   0.881437                91.153914
#
#      chainB_intf_avg_plddt_min_frag  RMSD_all_atom_peptide_classification  \
# 60                        73.986000                     correct_sidechain
# 63                        73.986000                     correct_sidechain
# 83                        88.666667                     correct_sidechain
# 90                        88.666667                     correct_sidechain
# 157                       94.980000                     correct_sidechain
# ..                              ...                                   ...
# 304                       96.447646                     correct_sidechain
# 222                       89.547501                     correct_sidechain
# 218                       89.547501                     correct_sidechain
# 297                       81.823750                     correct_sidechain
# 280                       81.823750                     correct_sidechain
#
#      RMSD_all_atom_peptide_fold_change  DockQ_ext-DockQ_min  \
# 60                            0.857058                0.072
# 63                            0.240583                0.032
# 83                           -0.013629               -0.029
# 90                           -0.099920               -0.036
# 157                          -0.009569                0.004
# ..                                 ...                  ...
# 304                          -0.094566                0.006
# 222                          -0.142646               -0.043
# 218                           0.004811               -0.016
# 297                           0.363115                0.042
# 280                           0.560340                0.037
#
#      RMSD_all_atom_peptide_classification_min_frag
# 60                               correct_sidechain
# 63                               correct_sidechain
# 83                               correct_sidechain
# 90                               correct_sidechain
# 157                              correct_sidechain
# ..                                             ...
# 304                              correct_sidechain
# 222                              correct_sidechain
# 218                              correct_sidechain
# 297                              correct_sidechain
# 280                              correct_sidechain
#
# [68 rows x 37 columns]

# %%
dst = '/Volumes/imb-luckgr/projects/dmi_predictor/Julia/AF-MMv2.2_extended_PRS_ext1_domain_ext0_1_motif'
for i, r in merged_df[merged_df['motif_ext_index'].isin([0,1]) & merged_df['domain_ext_index'].isin([1])].sort_values('dmi_name').iterrows():
    prediction_name = r['prediction_name']
    run_id = r['run_id']
    os.makedirs(f'{dst}/{prediction_name}')
    for ind in range(5):
        shutil.copy(src=f'/Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/{run_id}/{prediction_name}/ranked_{ind}_superimpose.pse',
                    dst=f'{dst}/{prediction_name}')

# %%
merged_df.columns
# Out:
# Index(['project_name', 'prediction_name', 'run_id', 'chainA_length',
#        'chainB_length', 'model_id', 'model_confidence',
#        'chainA_intf_avg_plddt', 'chainB_intf_avg_plddt', 'intf_avg_plddt',
#        'num_chainA_intf_res', 'num_chainB_intf_res', 'num_res_res_contact',
#        'num_atom_atom_contact', 'RMSD_domain', 'num_align_atoms_domain',
#        'align_score_domain', 'num_align_resi_domain', 'RMSD_backbone_peptide',
#        'RMSD_all_atom_peptide', 'known_motif_plddt', 'DockQ', 'iRMS', 'LRMS',
#        'Fnonnat', 'dmi_name', 'domain_ext_index', 'motif_ext_index',
#        'RMSD_all_atom_peptide_min_frag', 'DockQ_min_frag',
#        'model_confidence_min_frag', 'intf_avg_plddt_min_frag',
#        'chainB_intf_avg_plddt_min_frag',
#        'RMSD_all_atom_peptide_classification',
#        'RMSD_all_atom_peptide_fold_change', 'DockQ_ext-DockQ_min',
#        'RMSD_all_atom_peptide_classification_min_frag'],
#       dtype='object')

# %%
sel_pred = merged_df[merged_df['motif_ext_index'].isin([0,1]) & merged_df['domain_ext_index'].isin([1])].prediction_name.values
sel_pred
# Out:
# array(['run39_DEG_SIAH_1_M50_M76_D1_D282', 'run39_DEG_SIAH_1_Mmin_DFL',
#        'run39_DOC_USP7_MATH_1_M392_M406_D1_D204',
#        'run39_DOC_USP7_MATH_1_Mmin_D1_D204',
#        'run39_LIG_PCNA_PIPBox_1_M134_M163_D1_D261',
#        'run39_LIG_PCNA_PIPBox_1_Mmin_D1_D261',
#        'run39_DEG_APCC_KENBOX_2_M20_M34_D1_D499',
#        'run39_DEG_APCC_KENBOX_2_Mmin_D1_D499',
#        'run39_DEG_Kelch_Keap1_1_M71_M88_D295_D624',
#        'run39_DEG_Kelch_Keap1_1_Mmin_D295_D624',
#        'run39_LIG_TRFH_1_M253_M267_D1_D370',
#        'run39_LIG_TRFH_1_Mmin_D1_D370',
#        'run39_DOC_ANK_TNKS_1_M69_M92_D471_D669',
#        'run39_DOC_ANK_TNKS_1_Mmin_D471_D669',
#        'run39_DEG_MDM2_SWIB_1_M11_M34_D1_D290',
#        'run39_DEG_MDM2_SWIB_1_Mmin_D1_D290',
#        'run39_LIG_CAP-Gly_2_M568_M581_D1_D204',
#        'run39_LIG_CAP-Gly_2_Mmin_D1_D204',
#        'run39_LIG_HOMEOBOX_M176_M187_D242_D430',
#        'run39_LIG_HOMEOBOX_Mmin_D242_D430',
#        'run39_LIG_WW_1_M885_M895_D2925_D3362',
#        'run39_LIG_WW_1_Mmin_D2925_D3362',
#        'run39_LIG_BIR_III_2_Mmin_D240_D437',
#        'run39_LIG_BIR_III_2_M310_M324_D240_D437',
#        'run39_LIG_NRBOX_M682_M702_D262_D542',
#        'run39_LIG_NRBOX_Mmin_D262_D542',
#        'run39_TRG_AP2beta_CARGO_1_M245_M277_D542_D937',
#        'run39_TRG_AP2beta_CARGO_1_Mmin_D542_D937',
#        'run39_LIG_Vh1_VBS_1_M589_M645_D1_D471',
#        'run39_LIG_Vh1_VBS_1_Mmin_D1_D471',
#        'run39_LIG_CAP-Gly_1_Mmin_D1_D517',
#        'run39_LIG_CAP-Gly_1_M1432_M1438_D1_D517',
#        'run39_DOC_MAPK_JIP1_4_M336_M356_D1_D464',
#        'run39_DOC_MAPK_JIP1_4_Mmin_DFL',
#        'run39_DOC_USP7_UBL2_3_M1106_M1120_D528_D865',
#        'run39_DOC_USP7_UBL2_3_Mmin_D528_D865',
#        'run39_LIG_PCNA_TLS_4_M854_M870_D1_D261',
#        'run39_LIG_PCNA_TLS_4_Mmin_DFL',
#        'run39_LIG_PAM2_2_M1371_M1412_D373_D636',
#        'run39_LIG_PAM2_2_Mmin_D373_D636',
#        'run39_DOC_SPAK_OSR1_1_M1011_M1025_D301_D527',
#        'run39_DOC_SPAK_OSR1_1_Mmin_D301_D527',
#        'run39_LIG_OCRL_FandH_1_M210_M248_D534_D901',
#        'run39_LIG_OCRL_FandH_1_Mmin_D534_D901',
#        'run39_LIG_NBox_RRM_1_M20_M52_D1_D559',
#        'run39_LIG_NBox_RRM_1_Mmin_D1_D559',
#        'run39_LIG_REV1ctd_RIR_1_M553_M588_D1052_D1251',
#        'run39_LIG_REV1ctd_RIR_1_Mmin_D1052_D1251',
#        'run39_LIG_Pex14_3_M56_M73_D1_D377',
#        'run39_LIG_Pex14_3_Mmin_D1_D377',
#        'run39_LIG_LRP6_Inhibitor_1_M30_M50_D1_D362',
#        'run39_LIG_LRP6_Inhibitor_1_Mmin_D1_D362',
#        'run39_LIG_LIR_Gen_1_Mmin_DFL',
#        'run39_LIG_LIR_Gen_1_M719_M751_D1_D117',
#        'run39_LIG_RPA_C_Vert_M57_M104_D1_D270',
#        'run39_LIG_RPA_C_Vert_Mmin_D1_D270',
#        'run39_LIG_PDZ_Class_1_Mmin_D1185_D1492',
#        'run39_LIG_PDZ_Class_1_M1590_M1601_D1185_D1492',
#        'run39_LIG_GYF_M286_M312_D1_D341', 'run39_LIG_GYF_Mmin_DFL',
#        'run39_LIG_ULM_U2AF65_1_M6_M32_D340_D475',
#        'run39_LIG_ULM_U2AF65_1_Mmin_D340_D475',
#        'run39_LIG_EF_ALG2_ABM_1_M793_M819_D1_D191',
#        'run39_LIG_EF_ALG2_ABM_1_Mmin_D1_D191',
#        'run39_LIG_PAM2_1_M96_M127_D373_D636',
#        'run39_LIG_PAM2_1_Mmin_D373_D636',
#        'run40_LIG_CNOT1_NIM_1_Mmin_D1544_D2376',
#        'run40_LIG_CNOT1_NIM_1_M30_M59_D1544_D2376'], dtype=object)

# %%
ext_df[ext_df['prediction_name'].isin(sel_pred)].to_csv(f'{dst}/calculated_metrics.tsv',
                                 sep='\t')

# %%
merged_df.columns
# Out:
# Index(['project_name', 'prediction_name', 'run_id', 'chainA_length',
#        'chainB_length', 'model_id', 'model_confidence',
#        'chainA_intf_avg_plddt', 'chainB_intf_avg_plddt', 'intf_avg_plddt',
#        'pDockQ', 'iPAE', 'num_chainA_intf_res', 'num_chainB_intf_res',
#        'num_res_res_contact', 'num_atom_atom_contact', 'RMSD_domain',
#        'num_align_atoms_domain', 'align_score_domain', 'num_align_resi_domain',
#        'RMSD_backbone_peptide', 'RMSD_all_atom_peptide', 'known_motif_plddt',
#        'DockQ', 'iRMS', 'LRMS', 'Fnonnat', 'dmi_name', 'domain_ext_index',
#        'motif_ext_index', 'RMSD_all_atom_peptide_min_frag', 'DockQ_min_frag',
#        'model_confidence_min_frag', 'intf_avg_plddt_min_frag',
#        'chainB_intf_avg_plddt_min_frag', 'pDockQ_min_frag',
#        'RMSD_all_atom_peptide_classification',
#        'RMSD_all_atom_peptide_fold_change', 'DockQ_ext-DockQ_min',
#        'RMSD_all_atom_peptide_classification_min_frag'],
#       dtype='object')

# %%
merged_df[(merged_df['RMSD_all_atom_peptide_classification'] == 'wrong_pocket')]['dmi_name'].unique()
# Out:
# array(['DOC_USP7_MATH_1', 'DOC_ANK_TNKS_1', 'LIG_CAP-Gly_2',
#        'LIG_HOMEOBOX', 'LIG_BIR_III_2', 'LIG_NRBOX', 'LIG_Vh1_VBS_1',
#        'LIG_CAP-Gly_1', 'DOC_MAPK_JIP1_4', 'LIG_PCNA_TLS_4',
#        'LIG_REV1ctd_RIR_1', 'LIG_Pex14_3', 'LIG_LRP6_Inhibitor_1',
#        'LIG_RPA_C_Vert', 'LIG_PDZ_Class_1', 'LIG_GYF',
#        'LIG_EF_ALG2_ABM_1', 'LIG_CNOT1_NIM_1'], dtype=object)

# %% [markdown]
# ----
# Below is the code used to find problematic DMI type extensions

# %%
temp = merged_df[(merged_df['RMSD_all_atom_peptide_classification_min_frag'] == 'correct_pocket') & (merged_df['RMSD_all_atom_peptide_classification'] == 'wrong_pocket') & (merged_df['intf_avg_plddt'].notna()) & (merged_df['chainB_length'] > 20)].copy()
for i, r in temp.iterrows():
    prediction_name = r['prediction_name']
    run_id = r['run_id']
    model_id = r['model_id']
    print(f'load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/{run_id}/{prediction_name}/{model_id}_superimpose.pse')
# Out:
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run39/run39_LIG_CAP-Gly_2_M120_M581_D1_D288/ranked_0_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run46/run46_LIG_CAP-Gly_2_M120_M581_DFL/ranked_3_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run46/run46_LIG_CAP-Gly_2_MFL_D1_D204/ranked_1_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run46/run46_LIG_CAP-Gly_2_MFL_D1_D288/ranked_4_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run39/run39_LIG_HOMEOBOX_M164_M199_D30_D430/ranked_1_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run46/run46_LIG_HOMEOBOX_M164_M199_DFL/ranked_1_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run39/run39_LIG_HOMEOBOX_M156_M207_D30_D430/ranked_3_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run46/run46_LIG_Pex14_3_MFL_DFL/ranked_2_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run39/run39_LIG_LRP6_Inhibitor_1_M1_M85_D1_D422/ranked_2_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run39/run39_LIG_LRP6_Inhibitor_1_MFL_Dmin/ranked_3_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run46/run46_LIG_LRP6_Inhibitor_1_MFL_D1_D362/ranked_1_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run46/run46_LIG_LRP6_Inhibitor_1_MFL_D1_D422/ranked_2_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run46/run46_LIG_LRP6_Inhibitor_1_MFL_DFL/ranked_3_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run39/run39_LIG_LRP6_Inhibitor_1_M1_M149_Dmin/ranked_2_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run39/run39_LIG_LRP6_Inhibitor_1_M1_M149_D1_D362/ranked_0_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run39/run39_LIG_LRP6_Inhibitor_1_M1_M149_D1_D422/ranked_0_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run46/run46_LIG_LRP6_Inhibitor_1_M1_M149_DFL/ranked_0_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run40/run40_LIG_PDZ_Class_1_M853_M1601_D1084_D1593/ranked_1_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run40/run40_LIG_PDZ_Class_1_M853_M1601_Dmin/ranked_2_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run40/run40_LIG_PDZ_Class_1_M853_M1601_D1185_D1492/ranked_0_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run46/run46_LIG_PDZ_Class_1_MFL_D1185_D1492/ranked_2_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run39/run39_LIG_GYF_M277_M321_D1_D341/ranked_1_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run39/run39_LIG_GYF_M259_M339_Dmin/ranked_1_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run39/run39_LIG_GYF_M259_M339_D1_D341/ranked_0_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run39/run39_LIG_GYF_M241_M351_Dmin/ranked_0_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run39/run39_LIG_GYF_M241_M351_D1_D341/ranked_0_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run39/run39_LIG_GYF_M125_M351_Dmin/ranked_2_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run39/run39_LIG_GYF_M125_M351_D1_D341/ranked_3_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run39/run39_LIG_GYF_MFL_Dmin/ranked_2_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run46/run46_LIG_GYF_MFL_D1_D341/ranked_0_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run46/run46_LIG_EF_ALG2_ABM_1_MFL_DFL/ranked_2_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run40/run40_LIG_EF_ALG2_ABM_1_MFL_Dmin/ranked_3_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run39/run39_LIG_EF_ALG2_ABM_1_M403_M868_D1_D191/ranked_2_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run39/run39_LIG_EF_ALG2_ABM_1_M403_M868_Dmin/ranked_1_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run40/run40_LIG_CNOT1_NIM_1_M20_M69_D1544_D2376/ranked_3_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run40/run40_LIG_CNOT1_NIM_1_M20_M69_D1377_D2376/ranked_3_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run39/run39_LIG_CNOT1_NIM_1_M20_M69_Dmin/ranked_0_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run40/run40_LIG_CNOT1_NIM_1_M1_M109_D1544_D2376/ranked_3_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run40/run40_LIG_CNOT1_NIM_1_M1_M109_D1377_D2376/ranked_1_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run39/run39_LIG_CNOT1_NIM_1_M1_M109_Dmin/ranked_3_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run40/run40_LIG_CNOT1_NIM_1_M30_M59_D1544_D2376/ranked_4_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run40/run40_LIG_CNOT1_NIM_1_M30_M59_D1377_D2376/ranked_1_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run39/run39_LIG_CNOT1_NIM_1_M30_M59_Dmin/ranked_2_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run40/run40_LIG_CNOT1_NIM_1_M1_M89_D1544_D2376/ranked_3_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run40/run40_LIG_CNOT1_NIM_1_M1_M89_D1377_D2376/ranked_2_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run39/run39_LIG_CNOT1_NIM_1_M1_M89_Dmin/ranked_4_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run40/run40_LIG_CNOT1_NIM_1_M1_M276_D1544_D2376/ranked_3_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run40/run40_LIG_CNOT1_NIM_1_M1_M276_D1377_D2376/ranked_0_superimpose.pse
# load /Volumes/imb-luckgr/projects/dmi_predictor/DMI_AF2_PRS/run39/run39_LIG_CNOT1_NIM_1_M1_M276_Dmin/ranked_2_superimpose.pse
